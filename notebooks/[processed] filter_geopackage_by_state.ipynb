# %%
import boto3
import geopandas as gpd
import pandas as pd
import folium
import numpy as np
from folium import GeoJson
from io import BytesIO

# %%
import sys
sys.path.append("/agrilearn_app/agrilearn/")
from agrilearn.utils import s3_utils, str_utils

# %% [markdown]
# ### Global Variables

# %%
DATASET_PATH = "/agrilearn_app/datasets/v2/geopackage/crop_classification_raw-filtered-v2-with_cana.gpkg"

# %% [markdown]
# # 1. Read Datasets

# %%
df = gpd.read_file(DATASET_PATH)

# %%
df['dataset_part'].value_counts()
# Out:
# dataset_part
# train    66407
# test      3636
# val       3425
# Name: count, dtype: int64

# %%
df['monitoring_class'].value_counts()
# Out:
# monitoring_class
# SUGAR_CANE    35276
# SOYBEAN       29670
# CORN           5710
# COTTON         1639
# RICE           1173
# Name: count, dtype: int64

# %%
df['cultura_2'].value_counts()
# Out:
# cultura_2
# cana_soca         30377
# cana_reformada     4019
# cana_expansao       880
# Name: count, dtype: int64

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 73468 rows and 41 columns

# %%
print(f"Dados de {df['start_season'].min()} a {df['end_season'].max()}")
# Out:
# Dados de 2017-09-01 a 2023-04-01

# %%
list(df.columns)
# Out:
# ['monitoring_class',
#  'period',
#  'fonte',
#  'cultura_2',
#  'state',
#  'area',
#  'meso',
#  'obs_extra',
#  'eopath_location',
#  'start_season',
#  'end_season',
#  'peak_start',
#  'peak_end',
#  'sentinel_eopatch_current',
#  'contour_score',
#  'contour_selected_timestamp',
#  'field_id',
#  'compac_index',
#  'planting_start',
#  'planting_end',
#  'cycle_start',
#  'cycle_end',
#  'LOS',
#  'is_valid',
#  'is_valid_cvt',
#  'start_of_season',
#  'end_of_season',
#  'peaks',
#  'length_of_season',
#  'key_bucket',
#  'dataset_part',
#  'local_eopatch_path',
#  'total_imagens_do_intervalo',
#  'total_de_imagem',
#  'status_missing_images',
#  'days_gap',
#  'dates_diff',
#  'mean_dates_diff',
#  'status_series_missing',
#  'monitoring_class_path',
#  'geometry']

# %%
df['dataset_part'].value_counts(normalize=True)*100
# Out:
# dataset_part
# train    90.389013
# test      4.949093
# val       4.661894
# Name: proportion, dtype: float64

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 73468 entries, 0 to 73467
# Data columns (total 41 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   monitoring_class            73468 non-null  object
#  1   period                      73468 non-null  object
#  2   fonte                       73468 non-null  object
#  3   cultura_2                   35276 non-null  object
#  4   state                       73468 non-null  object
#  5   area                        73468 non-null  float64
#  6   meso                        73468 non-null  int64
#  7   obs_extra                   73468 non-null  object
#  8   eopath_location             73468 non-null  object
#  9   start_season                73468 non-null  object
#  10  end_season                  73468 non-null  object
#  11  peak_start                  73468 non-null  object
#  12  peak_end                    73468 non-null  object
#  13  sentinel_eopatch_current    73468 non-null  object
#  14  contour_score               70471 non-null  float64
#  15  contour_selected_timestamp  73468 non-null  object
#  16  field_id                    73468 non-null  object
#  17  compac_index                73468 non-null  float64
#  18  planting_start              38192 non-null  object
#  19  planting_end                38192 non-null  object
#  20  cycle_start                 38192 non-null  datetime64[ms]
#  21  cycle_end                   38192 non-null  datetime64[ms]
#  22  LOS                         38192 non-null  object
#  23  is_valid                    38192 non-null  object
#  24  is_valid_cvt                0 non-null      object
#  25  start_of_season             38192 non-null  datetime64[ms]
#  26  end_of_season               38192 non-null  datetime64[ms]
#  27  peaks                       38192 non-null  object
#  28  length_of_season            38192 non-null  object
#  29  key_bucket                  38192 non-null  object
#  30  dataset_part                73468 non-null  object
#  31  local_eopatch_path          73468 non-null  object
#  32  total_imagens_do_intervalo  38192 non-null  object
#  33  total_de_imagem             38192 non-null  object
#  34  status_missing_images       38192 non-null  object
#  35  days_gap                    0 non-null      object
#  36  dates_diff                  0 non-null      object
#  37  mean_dates_diff             38192 non-null  float64
#  38  status_series_missing       38192 non-null  object
#  39  monitoring_class_path       73468 non-null  object
#  40  geometry                    73468 non-null  geometry
# dtypes: datetime64[ms](4), float64(4), geometry(1), int64(1), object(31)
# memory usage: 23.0+ MB

# %% [markdown]
# # 2. Data Analysis

# %% [markdown]
# ### 2.1 Analysing Target y (monitoring_class)

# %%
pd.concat([df['monitoring_class'].value_counts(), df['monitoring_class'].value_counts(normalize=True)*100], axis=1)
# Out:
#                   count  proportion
# monitoring_class
# SUGAR_CANE        35276   48.015463
# SOYBEAN           29670   40.384929
# CORN               5710    7.772091
# COTTON             1639    2.230903
# RICE               1173    1.596613

# %% [markdown]
# ### 2.2 Analysing fonte de dados

# %%
pd.concat([df['fonte'].value_counts(), df['fonte'].value_counts(normalize=True)*100], axis=1)
# Out:
#                                        count  proportion
# fonte
# Agrosatélite - Grãos Brasil 2021/2022  19185   26.113410
# Agrosatélite - Grãos Brasil 2020/2021  17834   24.274514
# Agrosatélite - Canasat 2022/23         12061   16.416671
# Agrosatélite - Canasat 2021/2022       11903   16.201612
# Agrosatélite - Canasat 2023/2024       11312   15.397180
# Conab - Arroz Irrigado 2019/2020         595    0.809876
# Conab - Arroz Irrigado 2018/2019         341    0.464148
# Conab - Arroz Irrigado 2017/2018         206    0.280394
# Conab - Arroz Irrigado 2021/2022          31    0.042195

# %% [markdown]
# ### 2.3 Analysing dados por estado

# %%
pd.concat([df['state'].value_counts(), df['state'].value_counts(normalize=True)*100], axis=1)
# Out:
#        count  proportion
# state
# SP     16526   22.494147
# PR      9689   13.188055
# MT      9504   12.936244
# MG      9434   12.840965
# GO      7729   10.520226
# MS      7274    9.900909
# RS      3338    4.543475
# TO      2634    3.585234
# MA      1781    2.424185
# BA      1193    1.623836
# PI      1158    1.576196
# RO      1066    1.450972
# PA       935    1.272663
# SC       710    0.966407
# RR       275    0.374313
# DF       156    0.212337
# AP        39    0.053084
# AC        27    0.036751

# %% [markdown]
# ### 2.6 Analysis field_id (existem IDs duplicados para os talhões)

# %%
df['field_id'].nunique()
# Out:
# 67829

# %%
df[df.duplicated(['field_id','period'])]
# Out:
#       monitoring_class     period                                  fonte  \
# 27054          SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 27060          SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 27071          SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 27077          SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 27095          SOYBEAN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# ...                ...        ...                                    ...
# 73457       SUGAR_CANE  2020/2021       Agrosatélite - Canasat 2021/2022
# 73458       SUGAR_CANE  2021/2022         Agrosatélite - Canasat 2022/23
# 73459       SUGAR_CANE  2021/2022         Agrosatélite - Canasat 2022/23
# 73464       SUGAR_CANE  2021/2022         Agrosatélite - Canasat 2022/23
# 73466       SUGAR_CANE  2021/2022         Agrosatélite - Canasat 2022/23
#
#        cultura_2 state       area  meso obs_extra  \
# 27054       None    RO   551422.0     3
# 27060       None    RO  3148591.0     4
# 27071       None    RO  2135605.0     7
# 27077       None    PA   568770.0    31
# 27095       None    PA  1404261.0    42
# ...          ...   ...        ...   ...       ...
# 73457  cana_soca    GO   520114.0   558
# 73458  cana_soca    GO  7609666.0   558
# 73459  cana_soca    GO  7609666.0   558
# 73464  cana_soca    GO  7609666.0   558
# 73466  cana_soca    GO  7609666.0   558
#
#                                          eopath_location start_season  ...  \
# 27054  start_2021-10-01_end_2022-05-01_monitoring_cla...   2021-10-01  ...
# 27060  start_2021-10-01_end_2022-05-01_monitoring_cla...   2021-10-01  ...
# 27071  start_2021-10-01_end_2022-05-01_monitoring_cla...   2021-10-01  ...
# 27077  start_2021-10-01_end_2022-09-01_monitoring_cla...   2021-10-01  ...
# 27095  start_2020-10-01_end_2021-09-01_monitoring_cla...   2020-10-01  ...
# ...                                                  ...          ...  ...
# 73457  start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01  ...
# 73458  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01  ...
# 73459  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01  ...
# 73464  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01  ...
# 73466  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01  ...
#
#                                       local_eopatch_path  \
# 27054  /agrilearn_app/datasets/eopatchs/processed/soy...
# 27060  /agrilearn_app/datasets/eopatchs/processed/soy...
# 27071  /agrilearn_app/datasets/eopatchs/processed/soy...
# 27077  /agrilearn_app/datasets/eopatchs/processed/soy...
# 27095  /agrilearn_app/datasets/eopatchs/processed/soy...
# ...                                                  ...
# 73457  /agrilearn_app/datasets/eopatchs/processed/can...
# 73458  /agrilearn_app/datasets/eopatchs/processed/can...
# 73459  /agrilearn_app/datasets/eopatchs/processed/can...
# 73464  /agrilearn_app/datasets/eopatchs/processed/can...
# 73466  /agrilearn_app/datasets/eopatchs/processed/can...
#
#       total_imagens_do_intervalo total_de_imagem status_missing_images  \
# 27054                         49              31                    OK
# 27060                         49              23                    OK
# 27071                         49              25                    OK
# 27077                         49              48                    OK
# 27095                         49              26                    OK
# ...                          ...             ...                   ...
# 73457                       None            None                  None
# 73458                       None            None                  None
# 73459                       None            None                  None
# 73464                       None            None                  None
# 73466                       None            None                  None
#
#        days_gap dates_diff mean_dates_diff  status_series_missing  \
# 27054      None       None            5.17                     OK
# 27060      None       None            5.23                     OK
# 27071      None       None            5.00                     OK
# 27077      None       None            2.51                     OK
# 27095      None       None            5.20                     OK
# ...         ...        ...             ...                    ...
# 73457      None       None             NaN                   None
# 73458      None       None             NaN                   None
# 73459      None       None             NaN                   None
# 73464      None       None             NaN                   None
# 73466      None       None             NaN                   None
#
#       monitoring_class_path                                           geometry
# 27054               soybean  POLYGON ((-62.38324 -10.12717, -62.38324 -10.1...
# 27060               soybean  POLYGON ((-62.01629 -11.33566, -62.01628 -11.3...
# 27071               soybean  POLYGON ((-60.58 -13.51871, -60.58 -13.51845, ...
# 27077               soybean  POLYGON ((-54.4106 -2.77062, -54.41037 -2.7716...
# 27095               soybean  MULTIPOLYGON (((-48.91709 -3.4195, -48.91695 -...
# ...                     ...                                                ...
# 73457                  cana  POLYGON ((-50.97791 -19.31829, -50.9795 -19.31...
# 73458                  cana  POLYGON ((-50.95173 -19.29924, -50.95077 -19.2...
# 73459                  cana  POLYGON ((-50.96747 -19.30071, -50.96747 -19.3...
# 73464                  cana  POLYGON ((-50.96251 -19.31623, -50.96498 -19.3...
# 73466                  cana  MULTIPOLYGON (((-50.95141 -19.31792, -50.95255...
#
# [2171 rows x 41 columns]

# %%
df[df.duplicated(['field_id','period'])]['field_id'].unique()
# Out:
# array(['9_2', '14_3', '23_1', ..., '559_3', '559_9', '559_12'],
#       dtype=object)

# %%
#df[df['field_id'].isin(['0_6'])].to_csv('/agrilearn_app/datasets/cana-v1/csvs/duplicated_lines_CANA-sample-02.csv')

# %%
df[['cultura_2', 'monitoring_class']]
# Out:
#        cultura_2 monitoring_class
# 0           None          SOYBEAN
# 1           None          SOYBEAN
# 2           None          SOYBEAN
# 3           None          SOYBEAN
# 4           None          SOYBEAN
# ...          ...              ...
# 73463  cana_soca       SUGAR_CANE
# 73464  cana_soca       SUGAR_CANE
# 73465  cana_soca       SUGAR_CANE
# 73466  cana_soca       SUGAR_CANE
# 73467  cana_soca       SUGAR_CANE
#
# [73468 rows x 2 columns]

# %% [markdown]
# # 3. Analysis culture per state

# %%
df[df['state'].isin(['BA', 'RS', 'MT', 'SP'])].groupby(['state', 'dataset_part']).agg({'monitoring_class':'value_counts'})
# Out:
#                                      monitoring_class
# state dataset_part monitoring_class
# BA    test         SOYBEAN                         38
#                    COTTON                          15
#                    CORN                            14
#       train        SOYBEAN                        489
#                    COTTON                         338
#                    CORN                           212
#       val          SOYBEAN                         34
#                    COTTON                          30
#                    CORN                            23
# MT    test         SUGAR_CANE                     198
#                    SOYBEAN                        188
#                    COTTON                          60
#                    CORN                            39
#       train        SOYBEAN                       4176
#                    SUGAR_CANE                    3455
#                    COTTON                         614
#                    CORN                           288
#       val          SOYBEAN                        182
#                    SUGAR_CANE                     142
#                    COTTON                         124
#                    CORN                            38
# RS    test         SOYBEAN                        101
#                    RICE                            28
#                    CORN                            23
#       train        SOYBEAN                       2078
#                    RICE                           531
#                    CORN                           451
#       val          SOYBEAN                         60
#                    RICE                            36
#                    CORN                            30
# SP    test         SUGAR_CANE                     440
#                    SOYBEAN                        217
#                    CORN                            78
#                    COTTON                           2
#       train        SUGAR_CANE                   10609
#                    SOYBEAN                       3829
#                    CORN                           719
#                    COTTON                          12
#       val          SUGAR_CANE                     398
#                    SOYBEAN                        150
#                    CORN                            65
#                    COTTON                           7

# %%
#df[df['state'].isin(['BA'])].to_file("/agrilearn_app/datasets/v2/geopackage/crop-classification-with-cana-BH.gpkg", driver='GPKG', engine='fiona')
#df[df['state'].isin(['RS'])].to_file("/agrilearn_app/datasets/v2/geopackage/crop-classification-with-cana-RS.gpkg", driver='GPKG', engine='fiona')
#df[df['state'].isin(['MT'])].to_file("/agrilearn_app/datasets/v2/geopackage/crop-classification-with-cana-MT.gpkg", driver='GPKG', engine='fiona')
df[df['state'].isin(['SP'])].to_file("/agrilearn_app/datasets/v2/geopackage/crop-classification-with-cana-SP.gpkg", driver='GPKG', engine='fiona')
