# %%
import boto3
import geopandas as gpd
import pandas as pd
import folium
import numpy as np
from folium import GeoJson
from io import BytesIO

# %%
import sys
sys.path.append("/agrilearn_app/agrilearn/")
from agrilearn.utils import s3_utils, str_utils

# %% [markdown]
# ### Global Variables

# %%
DATASET_PATH_TRAIN = "/agrilearn_app/datasets/v1/geopackage/cana_train_fields_filtered.gpkg"
DATASET_PATH_VAL = "/agrilearn_app/datasets/v1/geopackage/cana_val_fields_filtered.gpkg"
DATASET_PATH_TEST = "/agrilearn_app/datasets/v1/geopackage/cana_test_fields_filtered.gpkg"

# %% [markdown]
# # 1. Read Datasets

# %%
df_train = gpd.read_file(DATASET_PATH_TRAIN)
df_val = gpd.read_file(DATASET_PATH_VAL)
df_test = gpd.read_file(DATASET_PATH_TEST)

df_train['dataset_part'] = 'train'
df_val['dataset_part'] = 'val'
df_test['dataset_part'] =  'test'

df = pd.concat([df_train, df_val, df_test])

# %%
df['dataset_part'].value_counts()
# Out:
# dataset_part
# train    32229
# test      1591
# val       1456
# Name: count, dtype: int64

# %%
df['monitoring_class'].value_counts()
# Out:
# monitoring_class
# SUGAR_CANE    35276
# Name: count, dtype: int64

# %%
df['cultura_2'].value_counts()
# Out:
# cultura_2
# cana_soca         30377
# cana_reformada     4019
# cana_expansao       880
# Name: count, dtype: int64

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 35276 rows and 20 columns

# %%
print(f"Dados de {df['start_season'].min()} a {df['end_season'].max()}")
# Out:
# Dados de 2020-04-01 a 2023-04-01

# %%
list(df.columns)
# Out:
# ['monitoring_class',
#  'period',
#  'fonte',
#  'cultura_2',
#  'state',
#  'area',
#  'meso',
#  'obs_extra',
#  'eopath_location',
#  'start_season',
#  'end_season',
#  'peak_start',
#  'peak_end',
#  'sentinel_eopatch_current',
#  'contour_score',
#  'contour_selected_timestamp',
#  'field_id',
#  'compac_index',
#  'geometry',
#  'dataset_part']

# %%
df['dataset_part'].value_counts(normalize=True)*100
# Out:
# dataset_part
# train    91.362399
# test      4.510149
# val       4.127452
# Name: proportion, dtype: float64

# %%
df.to_file("/agrilearn_app/datasets/v1/geopackage/cana_fields_filtered.gpkg", 
           driver='GPKG', 
           engine='fiona')

# %% [markdown]
# # 2. Data Understading

# %% [markdown]
# ### 2.1 Data description
# - monitoring_class:** é a cultura de interesse dp cliente ou da amostra de treinamento (SOYBEAN, CORN)
# - period:  a safra agricola (2023/2024, 2024/2025)
# - state: é o estado do polígono
# - field_id: id do talhão
# - fonte: a origem dos dados (mapas temáticos, banco de dados)
# - area:
# - micro:
# - start_season: é a data que inicia a safra pra determinada cultura (monitoring_class) e safra (period)
# - end_season: é a data que termina a safra pra determinada cultura (monitoring_class) e safra (period)
# - peak_start: é a data que inicia o período em que pode ocorrer o pico pra determinada cultura (monitoring_class) e safra (period)
# - peak_end: é a data que termina o período em que pode ocorrer o pico pra determinada cultura (monitoring_class) e safra (period) (Obs: temos um calendário pra isso, um arquivo yaml)
# - start_of_cycle: data do inio do cultivo segundo o calendário agrícola
# - end_of_cycle: data do fim do caledário de cuiltivo segundo calendário agrícola
# - length_of_cycle:
# - start_of_season: data da emergencia da cultura
# - end_of_season: data da colheita da cultura
# - peak_of_season: data do pico vegetativo da cultura
# - length_of_season: Duração do cultivo
# - eopath_location: é caminho onde o eopatch está salvo (imagens p/ inferência)
# - geometry: é a geometria do polígono]

# %% [markdown]
# # 3. Data Processing

# %% [markdown]
# ### 3.1 Check the Data formatation

# %%
df.isna().sum()
# Out:
# monitoring_class                 0
# period                           0
# fonte                            0
# cultura_2                        0
# state                            0
# area                             0
# meso                             0
# obs_extra                        0
# eopath_location                  0
# start_season                     0
# end_season                       0
# peak_start                       0
# peak_end                         0
# sentinel_eopatch_current         0
# contour_score                 1823
# contour_selected_timestamp       0
# field_id                         0
# compac_index                     0
# geometry                         0
# dataset_part                     0
# dtype: int64

# %% [markdown]
# ### 3.2 Vamos manter os dados nulos no campo ``contour_score``

# %%
df[df['contour_score'].isna()]
# Out:
#      monitoring_class     period                             fonte  \
# 317        SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23
# 318        SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23
# 319        SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23
# 320        SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23
# 321        SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23
# ...               ...        ...                               ...
# 1412       SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022
# 1413       SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022
# 1414       SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022
# 1415       SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022
# 1459       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23
#
#            cultura_2 state       area  meso obs_extra  \
# 317   cana_reformada    TO  4247067.0    61
# 318   cana_reformada    TO  4247067.0    61
# 319   cana_reformada    TO  4247067.0    61
# 320   cana_reformada    TO  4247067.0    61
# 321   cana_reformada    TO  4247067.0    61
# ...              ...   ...        ...   ...       ...
# 1412       cana_soca    GO  1567914.0   547
# 1413       cana_soca    GO  1567914.0   547
# 1414       cana_soca    GO  1567914.0   547
# 1415       cana_soca    GO  1567914.0   547
# 1459  cana_reformada    GO   127053.0   549
#
#                                         eopath_location start_season  \
# 317   start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 318   start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 319   start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 320   start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 321   start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# ...                                                 ...          ...
# 1412  start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 1413  start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 1414  start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 1415  start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 1459  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
#
#       end_season  peak_start    peak_end  \
# 317   2022-04-01  2021-04-01  2022-04-01
# 318   2022-04-01  2021-04-01  2022-04-01
# 319   2022-04-01  2021-04-01  2022-04-01
# 320   2022-04-01  2021-04-01  2022-04-01
# 321   2022-04-01  2021-04-01  2022-04-01
# ...          ...         ...         ...
# 1412  2021-04-01  2020-04-01  2021-04-01
# 1413  2021-04-01  2020-04-01  2021-04-01
# 1414  2021-04-01  2020-04-01  2021-04-01
# 1415  2021-04-01  2020-04-01  2021-04-01
# 1459  2022-04-01  2021-04-01  2022-04-01
#
#                                sentinel_eopatch_current  contour_score  \
# 317   start_2021-04-01_end_2022-04-01_monitoring_cla...            NaN
# 318   start_2021-04-01_end_2022-04-01_monitoring_cla...            NaN
# 319   start_2021-04-01_end_2022-04-01_monitoring_cla...            NaN
# 320   start_2021-04-01_end_2022-04-01_monitoring_cla...            NaN
# 321   start_2021-04-01_end_2022-04-01_monitoring_cla...            NaN
# ...                                                 ...            ...
# 1412  start_2020-04-01_end_2021-04-01_monitoring_cla...            NaN
# 1413  start_2020-04-01_end_2021-04-01_monitoring_cla...            NaN
# 1414  start_2020-04-01_end_2021-04-01_monitoring_cla...            NaN
# 1415  start_2020-04-01_end_2021-04-01_monitoring_cla...            NaN
# 1459  start_2021-04-01_end_2022-04-01_monitoring_cla...            NaN
#
#      contour_selected_timestamp field_id  compac_index  \
# 317                  2022-03-13     33_3      1.422140
# 318                  2022-03-13     33_7      1.633626
# 319                  2022-03-13     33_8      1.524014
# 320                  2022-03-13     33_9      1.683029
# 321                  2022-03-13    33_10      1.527210
# ...                         ...      ...           ...
# 1412                 2021-02-01    520_7      1.445176
# 1413                 2021-02-01    520_8      1.453617
# 1414                 2021-02-01   520_11      1.710181
# 1415                 2021-02-01   520_13      1.484750
# 1459                 2022-03-28    527_1      1.505387
#
#                                                geometry dataset_part
# 317   POLYGON ((-48.02433 -9.30124, -48.0243 -9.3012...        train
# 318   POLYGON ((-48.03278 -9.30478, -48.03278 -9.304...        train
# 319   POLYGON ((-48.01997 -9.30964, -48.02001 -9.309...        train
# 320   POLYGON ((-48.03207 -9.30769, -48.03215 -9.307...        train
# 321   POLYGON ((-48.02722 -9.30705, -48.02712 -9.307...        train
# ...                                                 ...          ...
# 1412  POLYGON ((-49.55284 -15.48442, -49.55274 -15.4...         test
# 1413  POLYGON ((-49.54446 -15.4856, -49.54436 -15.48...         test
# 1414  POLYGON ((-49.55261 -15.49029, -49.55302 -15.4...         test
# 1415  POLYGON ((-49.54809 -15.48912, -49.54799 -15.4...         test
# 1459  POLYGON ((-49.94883 -16.2857, -49.94883 -16.28...         test
#
# [1823 rows x 20 columns]

# %%
df[df['contour_score'].isna()].shape[0] / df.shape[0]
# Out:
# 0.051678194806667424

# %%
df[df['contour_score'].isna()]['monitoring_class'].value_counts()
# Out:
# monitoring_class
# SUGAR_CANE    1823
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3 Data Formatation

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 35276 entries, 0 to 1590
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   monitoring_class            35276 non-null  object
#  1   period                      35276 non-null  object
#  2   fonte                       35276 non-null  object
#  3   cultura_2                   35276 non-null  object
#  4   state                       35276 non-null  object
#  5   area                        35276 non-null  float64
#  6   meso                        35276 non-null  int64
#  7   obs_extra                   35276 non-null  object
#  8   eopath_location             35276 non-null  object
#  9   start_season                35276 non-null  object
#  10  end_season                  35276 non-null  object
#  11  peak_start                  35276 non-null  object
#  12  peak_end                    35276 non-null  object
#  13  sentinel_eopatch_current    35276 non-null  object
#  14  contour_score               33453 non-null  float64
#  15  contour_selected_timestamp  35276 non-null  object
#  16  field_id                    35276 non-null  object
#  17  compac_index                35276 non-null  float64
#  18  geometry                    35276 non-null  geometry
#  19  dataset_part                35276 non-null  object
# dtypes: float64(3), geometry(1), int64(1), object(15)
# memory usage: 5.7+ MB

# %% [markdown]
# ### 3.3.1 Datetime variables

# %%
datetime_columns = ['start_season', 
                    'end_season', 
                    'peak_start', 
                    'peak_end']

df[datetime_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 35276 entries, 0 to 1590
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_season  35276 non-null  object
#  1   end_season    35276 non-null  object
#  2   peak_start    35276 non-null  object
#  3   peak_end      35276 non-null  object
# dtypes: object(4)
# memory usage: 1.3+ MB

# %%
for col in datetime_columns:
    print(col)
    df[col] = pd.to_datetime(df[col])
# Out:
# start_season
# end_season
# peak_start
# peak_end

# %% [markdown]
# #### 3.3.2 Integer variables

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 35276 entries, 0 to 1590
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   monitoring_class            35276 non-null  object
#  1   period                      35276 non-null  object
#  2   fonte                       35276 non-null  object
#  3   cultura_2                   35276 non-null  object
#  4   state                       35276 non-null  object
#  5   area                        35276 non-null  float64
#  6   meso                        35276 non-null  int64
#  7   obs_extra                   35276 non-null  object
#  8   eopath_location             35276 non-null  object
#  9   start_season                35276 non-null  datetime64[ns]
#  10  end_season                  35276 non-null  datetime64[ns]
#  11  peak_start                  35276 non-null  datetime64[ns]
#  12  peak_end                    35276 non-null  datetime64[ns]
#  13  sentinel_eopatch_current    35276 non-null  object
#  14  contour_score               33453 non-null  float64
#  15  contour_selected_timestamp  35276 non-null  object
#  16  field_id                    35276 non-null  object
#  17  compac_index                35276 non-null  float64
#  18  geometry                    35276 non-null  geometry
#  19  dataset_part                35276 non-null  object
# dtypes: datetime64[ns](4), float64(3), geometry(1), int64(1), object(11)
# memory usage: 5.7+ MB

# %% [markdown]
# # 4. Data Analysis

# %% [markdown]
# ### 4.1 Analysing Target y (monitoring_class)

# %%
pd.concat([df['monitoring_class'].value_counts(), df['monitoring_class'].value_counts(normalize=True)*100], axis=1)
# Out:
#                   count  proportion
# monitoring_class
# SUGAR_CANE        35276       100.0

# %% [markdown]
# ### 4.2 Analysing fonte de dados

# %%
pd.concat([df['fonte'].value_counts(), df['fonte'].value_counts(normalize=True)*100], axis=1)
# Out:
#                                   count  proportion
# fonte
# Agrosatélite - Canasat 2022/23    12061   34.190384
# Agrosatélite - Canasat 2021/2022  11903   33.742488
# Agrosatélite - Canasat 2023/2024  11312   32.067128

# %% [markdown]
# ### 4.3 Analysing dados por estado

# %%
pd.concat([df['state'].value_counts(), df['state'].value_counts(normalize=True)*100], axis=1)
# Out:
#        count  proportion
# state
# SP     11447   32.449824
# MG      5054   14.327021
# PR      4778   13.544620
# MS      4732   13.414219
# GO      4407   12.492913
# MT      3795   10.758022
# TO      1063    3.013380

# %% [markdown]
# ### 4.6 Analysis field_id (existem IDs duplicados para os talhões)

# %%
df['field_id'].nunique()
# Out:
# 34726

# %%
df[df.duplicated(['field_id','period'])]
# Out:
#      monitoring_class     period                             fonte  cultura_2  \
# 1          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 2          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 3          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 4          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 6          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# ...               ...        ...                               ...        ...
# 1580       SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 1581       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1582       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1587       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1589       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
#
#      state       area  meso obs_extra  \
# 1       TO  6375372.0    61
# 2       TO  6375372.0    61
# 3       TO  6375372.0    61
# 4       TO  6375372.0    61
# 6       TO  6375372.0    61
# ...    ...        ...   ...       ...
# 1580    GO   520114.0   558
# 1581    GO  7609666.0   558
# 1582    GO  7609666.0   558
# 1587    GO  7609666.0   558
# 1589    GO  7609666.0   558
#
#                                         eopath_location start_season  \
# 1     start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 2     start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 3     start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 4     start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 6     start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# ...                                                 ...          ...
# 1580  start_2020-04-01_end_2021-04-01_monitoring_cla...   2020-04-01
# 1581  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 1582  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 1587  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
# 1589  start_2021-04-01_end_2022-04-01_monitoring_cla...   2021-04-01
#
#      end_season peak_start   peak_end  \
# 1    2021-04-01 2020-04-01 2021-04-01
# 2    2021-04-01 2020-04-01 2021-04-01
# 3    2021-04-01 2020-04-01 2021-04-01
# 4    2021-04-01 2020-04-01 2021-04-01
# 6    2021-04-01 2020-04-01 2021-04-01
# ...         ...        ...        ...
# 1580 2021-04-01 2020-04-01 2021-04-01
# 1581 2022-04-01 2021-04-01 2022-04-01
# 1582 2022-04-01 2021-04-01 2022-04-01
# 1587 2022-04-01 2021-04-01 2022-04-01
# 1589 2022-04-01 2021-04-01 2022-04-01
#
#                                sentinel_eopatch_current  contour_score  \
# 1     start_2020-04-01_end_2021-04-01_monitoring_cla...       1.000000
# 2     start_2020-04-01_end_2021-04-01_monitoring_cla...       1.000000
# 3     start_2020-04-01_end_2021-04-01_monitoring_cla...       1.000000
# 4     start_2020-04-01_end_2021-04-01_monitoring_cla...       1.000000
# 6     start_2020-04-01_end_2021-04-01_monitoring_cla...       1.000000
# ...                                                 ...            ...
# 1580  start_2020-04-01_end_2021-04-01_monitoring_cla...       0.993173
# 1581  start_2021-04-01_end_2022-04-01_monitoring_cla...       1.000000
# 1582  start_2021-04-01_end_2022-04-01_monitoring_cla...       1.000000
# 1587  start_2021-04-01_end_2022-04-01_monitoring_cla...       1.000000
# 1589  start_2021-04-01_end_2022-04-01_monitoring_cla...       1.000000
#
#      contour_selected_timestamp field_id  compac_index  \
# 1                    2020-04-27      0_5      1.463128
# 2                    2020-04-27      0_6      1.353872
# 3                    2020-04-27      0_7      1.387676
# 4                    2020-04-27      0_8      1.471264
# 6                    2020-04-27     0_10      1.427358
# ...                         ...      ...           ...
# 1580                 2021-02-01    558_2      1.393636
# 1581                 2022-03-23    559_2      2.512049
# 1582                 2022-03-23    559_3      1.519327
# 1587                 2022-03-23    559_9      1.762405
# 1589                 2022-03-23   559_12      2.231472
#
#                                                geometry dataset_part
# 1     POLYGON ((-48.1934 -9.13491, -48.1933 -9.135, ...          val
# 2     POLYGON ((-48.20115 -9.136, -48.20115 -9.13609...          val
# 3     POLYGON ((-48.19504 -9.13663, -48.19504 -9.136...          val
# 4     POLYGON ((-48.18773 -9.13856, -48.18735 -9.138...          val
# 6     POLYGON ((-48.19905 -9.13935, -48.19905 -9.139...          val
# ...                                                 ...          ...
# 1580  POLYGON ((-50.97791 -19.31829, -50.9795 -19.31...         test
# 1581  POLYGON ((-50.95173 -19.29924, -50.95077 -19.2...         test
# 1582  POLYGON ((-50.96747 -19.30071, -50.96747 -19.3...         test
# 1587  POLYGON ((-50.96251 -19.31623, -50.96498 -19.3...         test
# 1589  MULTIPOLYGON (((-50.95141 -19.31792, -50.95255...         test
#
# [197 rows x 20 columns]

# %%
df[df.duplicated(['field_id','period'])]['field_id'].unique()
# Out:
# array(['0_5', '0_6', '0_7', '0_8', '0_10', '0_11', '0_12', '0_13', '0_14',
#        '1_6', '1_7', '1_8', '1_9', '1_11', '1_12', '1_13', '1_14', '1_15',
#        '1_17', '4_6', '4_8', '4_10', '4_11', '4_12', '4_13', '4_17',
#        '4_20', '4_22', '4_26', '4_34', '5_3', '33_9', '54_5', '79_6',
#        '79_9', '115_2', '119_6', '119_11', '155_1', '187_1', '200_7',
#        '214_3', '230_2', '231_3', '252_4', '268_1', '268_5', '295_3',
#        '305_0', '333_5', '335_5', '340_3', '366_1', '386_5', '417_2',
#        '419_2', '419_7', '425_2', '428_2', '433_1', '444_5', '444_7',
#        '444_8', '444_9', '444_12', '444_15', '444_20', '444_24', '444_25',
#        '444_28', '444_29', '444_30', '470_1', '481_2', '481_4', '491_1',
#        '533_1', '6_2', '6_3', '18_2', '20_2', '22_2', '23_1', '27_12',
#        '29_1', '29_8', '40_1', '41_1', '41_3', '44_2', '46_2', '54_3',
#        '55_6', '72_6', '72_7', '72_15', '72_25', '72_27', '72_28',
#        '72_36', '72_39', '72_41', '72_47', '84_1', '89_5', '90_4', '91_4',
#        '92_4', '96_2', '98_2', '118_4', '121_5', '128_3', '141_3',
#        '157_6', '189_3', '189_5', '202_3', '202_8', '203_4', '218_2',
#        '241_6', '249_2', '249_7', '272_7', '272_8', '272_10', '278_13',
#        '286_9', '289_4', '289_5', '289_7', '294_21', '294_47', '294_48',
#        '294_50', '294_69', '294_80', '294_81', '294_82', '294_90',
#        '294_91', '306_4', '308_4', '310_1', '321_2', '321_17', '322_1',
#        '342_9', '342_10', '359_1', '360_2', '362_3', '362_5', '367_3',
#        '367_5', '391_3', '406_0', '418_10', '431_3', '434_3', '438_2',
#        '438_3', '454_2', '454_4', '456_3', '456_4', '460_5', '465_2',
#        '465_4', '469_1', '469_5', '469_6', '469_30', '480_2', '480_5',
#        '484_3', '487_2', '487_6', '487_10', '488_7', '500_2', '505_3',
#        '505_4', '506_4', '512_3', '512_4', '520_8', '522_2', '542_1',
#        '542_7', '542_10', '558_2', '559_2', '559_3', '559_9', '559_12'],
#       dtype=object)

# %%
#df[df['field_id'].isin(['0_6'])].to_csv('/agrilearn_app/datasets/cana-v1/csvs/duplicated_lines_CANA-sample-02.csv')

# %%
df[['cultura_2', 'monitoring_class']]
# Out:
#       cultura_2 monitoring_class
# 0     cana_soca       SUGAR_CANE
# 1     cana_soca       SUGAR_CANE
# 2     cana_soca       SUGAR_CANE
# 3     cana_soca       SUGAR_CANE
# 4     cana_soca       SUGAR_CANE
# ...         ...              ...
# 1586  cana_soca       SUGAR_CANE
# 1587  cana_soca       SUGAR_CANE
# 1588  cana_soca       SUGAR_CANE
# 1589  cana_soca       SUGAR_CANE
# 1590  cana_soca       SUGAR_CANE
#
# [35276 rows x 2 columns]

# %% [markdown]
# ## 5. Generating Html Report

# %%
from ydata_profiling import ProfileReport
from ydata_profiling.config import Settings
# %matplotlib inline

# %%
df_copy = df.drop(columns=['cultura_2', 'geometry'])  # Supondo que 'cultura_2' seja a coluna problemática

# %%
df_e_object = df_copy.select_dtypes(exclude=['object'])
df_e_object
# Out:
#            area  meso start_season end_season peak_start   peak_end  \
# 0     3603383.0    58   2020-04-01 2021-04-01 2020-04-01 2021-04-01
# 1     3603383.0    58   2020-04-01 2021-04-01 2020-04-01 2021-04-01
# 2     3603383.0    58   2020-04-01 2021-04-01 2020-04-01 2021-04-01
# 3     3603383.0    58   2020-04-01 2021-04-01 2020-04-01 2021-04-01
# 4     3603383.0    58   2020-04-01 2021-04-01 2020-04-01 2021-04-01
# ...         ...   ...          ...        ...        ...        ...
# 1586  7609666.0   558   2021-04-01 2022-04-01 2021-04-01 2022-04-01
# 1587  7609666.0   558   2021-04-01 2022-04-01 2021-04-01 2022-04-01
# 1588  7609666.0   558   2021-04-01 2022-04-01 2021-04-01 2022-04-01
# 1589  7609666.0   558   2021-04-01 2022-04-01 2021-04-01 2022-04-01
# 1590  7609666.0   558   2021-04-01 2022-04-01 2021-04-01 2022-04-01
#
#       contour_score  compac_index
# 0               1.0      1.433508
# 1               1.0      1.705125
# 2               1.0      1.501758
# 3               1.0      1.493624
# 4               1.0      1.746982
# ...             ...           ...
# 1586            1.0      1.758666
# 1587            1.0      1.762405
# 1588            1.0      1.455945
# 1589            1.0      2.231472
# 1590            1.0      1.572972
#
# [35276 rows x 8 columns]

# %%
df_i_object = df_copy.select_dtypes(include=['object'])
df_i_object
# Out:
#      monitoring_class     period                             fonte state  \
# 0          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022    TO
# 1          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022    TO
# 2          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022    TO
# 3          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022    TO
# 4          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022    TO
# ...               ...        ...                               ...   ...
# 1586       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23    GO
# 1587       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23    GO
# 1588       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23    GO
# 1589       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23    GO
# 1590       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23    GO
#
#      obs_extra                                    eopath_location  \
# 0               start_2020-04-01_end_2021-04-01_monitoring_cla...
# 1               start_2020-04-01_end_2021-04-01_monitoring_cla...
# 2               start_2020-04-01_end_2021-04-01_monitoring_cla...
# 3               start_2020-04-01_end_2021-04-01_monitoring_cla...
# 4               start_2020-04-01_end_2021-04-01_monitoring_cla...
# ...        ...                                                ...
# 1586            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1587            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1588            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1589            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1590            start_2021-04-01_end_2022-04-01_monitoring_cla...
#
#                                sentinel_eopatch_current  \
# 0     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 1     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 2     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 3     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 4     start_2020-04-01_end_2021-04-01_monitoring_cla...
# ...                                                 ...
# 1586  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1587  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1588  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1589  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1590  start_2021-04-01_end_2022-04-01_monitoring_cla...
#
#      contour_selected_timestamp field_id dataset_part
# 0                    2020-04-27      0_2        train
# 1                    2020-04-27      0_3        train
# 2                    2020-04-27      0_5        train
# 3                    2020-04-27      0_6        train
# 4                    2020-04-27      0_7        train
# ...                         ...      ...          ...
# 1586                 2022-03-23    559_8         test
# 1587                 2022-03-23    559_9         test
# 1588                 2022-03-23   559_11         test
# 1589                 2022-03-23   559_12         test
# 1590                 2022-03-23   559_13         test
#
# [35276 rows x 10 columns]

# %%
df_e_object_colums = df_copy.select_dtypes(exclude=['object']).columns

# %%
title = "data_report_14_11_2024_cana_data"
config = Settings()
config.vars.cat.words = False  # Desativa a nuvem de palavras
report  = ProfileReport(df=df_copy[list(df_e_object_colums) + ['monitoring_class', 'state', 'period', 'fonte']], 
                        title=title,
                        minimal=False,
                        config=config)

report.to_file(f'{title}.html')
# Out:
# /home/ec2-user/.local/lib/python3.10/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /home/ec2-user/.local/lib/python3.10/site-packages/ydata_profiling/model/correlations.py:66: UserWarning: There was an attempt to calculate the auto correlation, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(correlations={"auto": {"calculate": False}})`
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'cannot reindex on an axis with duplicate labels')
#   warnings.warn(
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_number = df.select_dtypes(exclude=['float','int', 'datetime'])
df_number
# Out:
#      monitoring_class     period                             fonte  cultura_2  \
# 0          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 1          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 2          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 3          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# 4          SUGAR_CANE  2020/2021  Agrosatélite - Canasat 2021/2022  cana_soca
# ...               ...        ...                               ...        ...
# 1586       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1587       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1588       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1589       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
# 1590       SUGAR_CANE  2021/2022    Agrosatélite - Canasat 2022/23  cana_soca
#
#      state obs_extra                                    eopath_location  \
# 0       TO            start_2020-04-01_end_2021-04-01_monitoring_cla...
# 1       TO            start_2020-04-01_end_2021-04-01_monitoring_cla...
# 2       TO            start_2020-04-01_end_2021-04-01_monitoring_cla...
# 3       TO            start_2020-04-01_end_2021-04-01_monitoring_cla...
# 4       TO            start_2020-04-01_end_2021-04-01_monitoring_cla...
# ...    ...       ...                                                ...
# 1586    GO            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1587    GO            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1588    GO            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1589    GO            start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1590    GO            start_2021-04-01_end_2022-04-01_monitoring_cla...
#
#                                sentinel_eopatch_current  \
# 0     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 1     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 2     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 3     start_2020-04-01_end_2021-04-01_monitoring_cla...
# 4     start_2020-04-01_end_2021-04-01_monitoring_cla...
# ...                                                 ...
# 1586  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1587  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1588  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1589  start_2021-04-01_end_2022-04-01_monitoring_cla...
# 1590  start_2021-04-01_end_2022-04-01_monitoring_cla...
#
#      contour_selected_timestamp field_id  \
# 0                    2020-04-27      0_2
# 1                    2020-04-27      0_3
# 2                    2020-04-27      0_5
# 3                    2020-04-27      0_6
# 4                    2020-04-27      0_7
# ...                         ...      ...
# 1586                 2022-03-23    559_8
# 1587                 2022-03-23    559_9
# 1588                 2022-03-23   559_11
# 1589                 2022-03-23   559_12
# 1590                 2022-03-23   559_13
#
#                                                geometry dataset_part
# 0     POLYGON ((-48.34483 -8.91348, -48.34412 -8.913...        train
# 1     POLYGON ((-48.35083 -8.91933, -48.35008 -8.917...        train
# 2     POLYGON ((-48.343 -8.91709, -48.34291 -8.91718...        train
# 3     POLYGON ((-48.34644 -8.9189, -48.34626 -8.9190...        train
# 4     POLYGON ((-48.34119 -8.91971, -48.34119 -8.919...        train
# ...                                                 ...          ...
# 1586  POLYGON ((-50.96946 -19.31377, -50.97019 -19.3...         test
# 1587  POLYGON ((-50.96251 -19.31623, -50.96498 -19.3...         test
# 1588  POLYGON ((-50.9802 -19.31351, -50.9801 -19.313...         test
# 1589  MULTIPOLYGON (((-50.95141 -19.31792, -50.95255...         test
# 1590  POLYGON ((-50.97151 -19.31596, -50.97215 -19.3...         test
#
# [35276 rows x 12 columns]

# %% [markdown]
# # 6. Analysis culture per state

# %%
df[df['state'].isin(['BA', 'RS', 'MT'])].groupby('state').agg({'monitoring_class':'value_counts'})
# Out:
#                         monitoring_class
# state monitoring_class
# MT    SUGAR_CANE                    3795

# %%
# df[df['state'].isin(['BA'])].to_file("/agrilearn_app/datasets/geopackages/crop-classification-v3-bahia", driver='GPKG', engine='fiona')
# df[df['state'].isin(['RS'])].to_file("/agrilearn_app/datasets/geopackages/crop-classification-v3-rio-grande-do-sul", driver='GPKG', engine='fiona')
# df[df['state'].isin(['MT'])].to_file("/agrilearn_app/datasets/geopackages/crop-classification-v3-mato-grosso", driver='GPKG', engine='fiona')
