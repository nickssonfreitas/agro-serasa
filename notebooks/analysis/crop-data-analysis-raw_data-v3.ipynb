# %%
import boto3
import geopandas as gpd
from io import BytesIO
import pandas as pd
from folium import GeoJson
import folium
import numpy as np

# %%
import sys
sys.path.append("/agrilearn_app/agrilearn/")
from agrilearn.utils import s3_utils, str_utils

# %% [markdown]
# ### Global Variables

# %%
DATASET_PATH_TRAIN = "/agrilearn_app/datasets/geopackages/train_all_cultures_v3.gpkg"
DATASET_PATH_VAL = "/agrilearn_app/datasets/geopackages/val_all_cultures_v3.gpkg"
DATASET_PATH_TEST = "/agrilearn_app/datasets/geopackages/test_all_cultures_v3.gpkg"

# %% [markdown]
# # 1. Read Datasets

# %%
df_train = gpd.read_file(DATASET_PATH_TRAIN)
df_val = gpd.read_file(DATASET_PATH_VAL)
df_test = gpd.read_file(DATASET_PATH_TEST)
df_train['dataset_part'] = 'train'
df_val['dataset_part'] = 'val'
df_test['dataset_part'] =  'test'
df = pd.concat([df_train, df_val, df_test])

# %%
df.head()
# Out:
#   monitoring_class     period state field_id  \
# 0             CORN  2021/2022    RO   1231_0
# 1             CORN  2021/2022    RO   1231_1
# 2             CORN  2020/2021    RO   1232_0
# 3             CORN  2021/2022    RO   1233_1
# 4             CORN  2020/2021    RO   1235_1
#
#                                    fonte      area  micro start_season  \
# 0  Agrosatélite - Grãos Brasil 2021/2022  399481.0      0   2021-09-01
# 1  Agrosatélite - Grãos Brasil 2021/2022  399481.0      0   2021-09-01
# 2  Agrosatélite - Grãos Brasil 2020/2021  254481.0      2   2020-09-01
# 3  Agrosatélite - Grãos Brasil 2021/2022  266350.0      2   2021-09-01
# 4  Agrosatélite - Grãos Brasil 2020/2021  393922.0      5   2020-09-01
#
#    end_season  peak_start  ...       start_of_cycle         end_of_cycle  \
# 0  2022-06-01  2021-11-01  ...  2021-11-16 00:00:00  2022-04-10 00:00:00
# 1  2022-06-01  2021-11-01  ...  2021-10-22 00:00:00  2022-03-11 00:00:00
# 2  2021-06-01  2020-11-01  ...  2020-11-11 00:00:00  2021-03-16 00:00:00
# 3  2022-06-01  2021-11-01  ...  2021-11-01 00:00:00  2022-03-26 00:00:00
# 4  2021-06-01  2020-11-01  ...  2020-10-24 00:00:00  2021-03-13 00:00:00
#
#   length_of_cycle      start_of_season        end_of_season  \
# 0             145  2021-10-18 00:00:00  2022-03-23 00:00:00
# 1             140  2021-11-07 00:00:00  2022-03-22 00:00:00
# 2             125  2020-11-19 00:00:00  2021-03-19 00:00:00
# 3             145  2021-11-02 00:00:00  2022-03-10 00:00:00
# 4             140  2020-11-06 00:00:00  2021-03-09 00:00:00
#
#         peak_of_season length_of_season  \
# 0  2022-01-15T00:00:00              156
# 1  2022-01-15T00:00:00              135
# 2  2021-01-25T00:00:00              120
# 3  2022-01-15T00:00:00              128
# 4  2020-12-13T00:00:00              123
#
#                                      eopath_location  \
# 0  start_2021-09-01_end_2022-06-01_monitoring_cla...
# 1  start_2021-09-01_end_2022-06-01_monitoring_cla...
# 2  start_2020-09-01_end_2021-06-01_monitoring_cla...
# 3  start_2021-09-01_end_2022-06-01_monitoring_cla...
# 4  start_2020-09-01_end_2021-06-01_monitoring_cla...
#
#                                             geometry dataset_part
# 0  MULTIPOLYGON (((-63.61826 -10.32938, -63.61796...        train
# 1  MULTIPOLYGON (((-63.61728 -10.34225, -63.61837...        train
# 2  MULTIPOLYGON (((-62.23076 -9.81551, -62.23116 ...        train
# 3  MULTIPOLYGON (((-63.09362 -9.90218, -63.09386 ...        train
# 4  MULTIPOLYGON (((-61.8818 -12.05653, -61.8818 -...        train
#
# [5 rows x 21 columns]

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 46642 rows and 21 columns

# %%
print(f"Dados de {df['start_season'].min()} a {df['end_season'].max()}")
# Out:
# Dados de 2017-09-01 a 2024-01-01

# %%
list(df.columns)
# Out:
# ['monitoring_class',
#  'period',
#  'state',
#  'field_id',
#  'fonte',
#  'area',
#  'micro',
#  'start_season',
#  'end_season',
#  'peak_start',
#  'peak_end',
#  'start_of_cycle',
#  'end_of_cycle',
#  'length_of_cycle',
#  'start_of_season',
#  'end_of_season',
#  'peak_of_season',
#  'length_of_season',
#  'eopath_location',
#  'geometry',
#  'dataset_part']

# %% [markdown]
# # 2. Data Understading

# %% [markdown]
# ### 2.1 Data description
# - monitoring_class:** é a cultura de interesse dp cliente ou da amostra de treinamento (SOYBEAN, CORN)
# - period:  a safra agricola (2023/2024, 2024/2025)
# - state: é o estado do polígono
# - field_id: id do talhão
# - fonte: a origem dos dados (mapas temáticos, banco de dados)
# - area:
# - micro:
# - start_season: é a data que inicia a safra pra determinada cultura (monitoring_class) e safra (period)
# - end_season: é a data que termina a safra pra determinada cultura (monitoring_class) e safra (period)
# - peak_start: é a data que inicia o período em que pode ocorrer o pico pra determinada cultura (monitoring_class) e safra (period)
# - peak_end: é a data que termina o período em que pode ocorrer o pico pra determinada cultura (monitoring_class) e safra (period) (Obs: temos um calendário pra isso, um arquivo yaml)
# - start_of_cycle: data do inio do cultivo segundo o calendário agrícola
# - end_of_cycle: data do fim do caledário de cuiltivo segundo calendário agrícola
# - length_of_cycle:
# - start_of_season: data da emergencia da cultura
# - end_of_season: data da colheita da cultura
# - peak_of_season: data do pico vegetativo da cultura
# - length_of_season: Duração do cultivo
# - eopath_location: é caminho onde o eopatch está salvo (imagens p/ inferência)
# - geometry: é a geometria do polígono]

# %% [markdown]
# # 3. Data Processing

# %% [markdown]
# ### 3.1 Check the Data formatation

# %%
df.isna().sum()
# Out:
# monitoring_class       0
# period                 0
# state                  0
# field_id            8450
# fonte                  0
# area                   0
# micro                  0
# start_season           0
# end_season             0
# peak_start             0
# peak_end               0
# start_of_cycle         0
# end_of_cycle           0
# length_of_cycle        0
# start_of_season        0
# end_of_season          0
# peak_of_season         0
# length_of_season       0
# eopath_location        0
# geometry               0
# dataset_part           0
# dtype: int64

# %% [markdown]
# ### 3.2 Vamos manter os dados nulos no campo ``field_id`` pois são os dados de trigo e não temos um padrão para gerar o field_id

# %%
df[df['field_id'].isna()].shape[0] / df.shape[0]
# Out:
# 0.1811671883709961

# %%
df[df['field_id'].isna()]['monitoring_class'].value_counts()
# Out:
# monitoring_class
# WHEAT    8450
# Name: count, dtype: int64

# %% [markdown]
# ### 3.3 Data Formatation

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 46642 entries, 0 to 4809
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   monitoring_class  46642 non-null  object
#  1   period            46642 non-null  object
#  2   state             46642 non-null  object
#  3   field_id          38192 non-null  object
#  4   fonte             46642 non-null  object
#  5   area              46642 non-null  float64
#  6   micro             46642 non-null  int64
#  7   start_season      46642 non-null  object
#  8   end_season        46642 non-null  object
#  9   peak_start        46642 non-null  object
#  10  peak_end          46642 non-null  object
#  11  start_of_cycle    46642 non-null  object
#  12  end_of_cycle      46642 non-null  object
#  13  length_of_cycle   46642 non-null  object
#  14  start_of_season   46642 non-null  object
#  15  end_of_season     46642 non-null  object
#  16  peak_of_season    46642 non-null  object
#  17  length_of_season  46642 non-null  object
#  18  eopath_location   46642 non-null  object
#  19  geometry          46642 non-null  geometry
#  20  dataset_part      46642 non-null  object
# dtypes: float64(1), geometry(1), int64(1), object(18)
# memory usage: 7.8+ MB

# %% [markdown]
# ### 3.3.1 Datetime variables

# %%
datetime_columns = ['start_season', 
                    'end_season', 
                    'peak_start', 
                    'peak_end']
                    #'start_of_cycle', 
                    #'end_of_cycle',
                    #'start_of_season',
                    #'end_of_season',
                    #'peak_of_season']

df[datetime_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 46642 entries, 0 to 4809
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_season  46642 non-null  datetime64[ns]
#  1   end_season    46642 non-null  datetime64[ns]
#  2   peak_start    46642 non-null  datetime64[ns]
#  3   peak_end      46642 non-null  datetime64[ns]
# dtypes: datetime64[ns](4)
# memory usage: 1.8 MB

# %%
df['start_of_cycle']
# Out:
# 0       2021-11-16 00:00:00
# 1       2021-10-22 00:00:00
# 2       2020-11-11 00:00:00
# 3       2021-11-01 00:00:00
# 4       2020-10-24 00:00:00
#                ...
# 4805             2023-04-04
# 4806             2023-04-04
# 4807             2023-05-04
# 4808             2023-04-04
# 4809             2023-04-04
# Name: start_of_cycle, Length: 46642, dtype: object

# %%
for col in datetime_columns:
    print(col)
    df[col] = pd.to_datetime(df[col])
# Out:
# start_season
# end_season
# peak_start
# peak_end

# %% [markdown]
# #### 3.3.2 Integer variables

# %%
df['length_of_season'] = df['length_of_season'].astype(int)

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Index: 46642 entries, 0 to 4809
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   monitoring_class  46642 non-null  object
#  1   period            46642 non-null  object
#  2   state             46642 non-null  object
#  3   field_id          38192 non-null  object
#  4   fonte             46642 non-null  object
#  5   area              46642 non-null  float64
#  6   micro             46642 non-null  int64
#  7   start_season      46642 non-null  datetime64[ns]
#  8   end_season        46642 non-null  datetime64[ns]
#  9   peak_start        46642 non-null  datetime64[ns]
#  10  peak_end          46642 non-null  datetime64[ns]
#  11  start_of_cycle    46642 non-null  object
#  12  end_of_cycle      46642 non-null  object
#  13  length_of_cycle   46642 non-null  object
#  14  start_of_season   46642 non-null  object
#  15  end_of_season     46642 non-null  object
#  16  peak_of_season    46642 non-null  object
#  17  length_of_season  46642 non-null  int64
#  18  eopath_location   46642 non-null  object
#  19  geometry          46642 non-null  geometry
#  20  dataset_part      46642 non-null  object
# dtypes: datetime64[ns](4), float64(1), geometry(1), int64(2), object(13)
# memory usage: 7.8+ MB

# %% [markdown]
# # 4. Data Analysis

# %% [markdown]
# ### 4.1 Analysing Target y (monitoring_class)

# %%
pd.concat([df['monitoring_class'].value_counts(), df['monitoring_class'].value_counts(normalize=True)*100], axis=1)
# Out:
#                   count  proportion
# monitoring_class
# SOYBEAN           29670   63.612195
# WHEAT              8450   18.116719
# CORN               5710   12.242185
# COTTON             1639    3.514000
# RICE               1173    2.514901

# %% [markdown]
# ### 4.2 Analysing fonte de dados

# %%
pd.concat([df['fonte'].value_counts(), df['fonte'].value_counts(normalize=True)*100], axis=1)
# Out:
#                                        count  proportion
# fonte
# Agrosatélite - Grãos Brasil 2021/2022  19185   41.132456
# Agrosatélite - Grãos Brasil 2020/2021  17834   38.235925
# Conab - Culturas de Inverno 2023/2023   8450   18.116719
# Conab - Arroz Irrigado 2019/2020         595    1.275674
# Conab - Arroz Irrigado 2018/2019         341    0.731101
# Conab - Arroz Irrigado 2017/2018         206    0.441662
# Conab - Arroz Irrigado 2021/2022          31    0.066464

# %% [markdown]
# ### 4.3 Analysing dados por estado

# %%
pd.concat([df['state'].value_counts(), df['state'].value_counts(normalize=True)*100], axis=1)
# Out:
#        count  proportion
# state
# PR     13360   28.643712
# MT      5709   12.240041
# SP      5079   10.889327
# MG      4380    9.390678
# RS      3338    7.156640
# GO      3322    7.122336
# MS      2542    5.450024
# MA      1781    3.818447
# TO      1571    3.368209
# BA      1193    2.557781
# PI      1158    2.482741
# RO      1066    2.285494
# PA       935    2.004631
# SC       711    1.524377
# RR       275    0.589597
# DF       156    0.334463
# AP        39    0.083616
# AC        27    0.057888

# %% [markdown]
# ### 4.6 Analysis field_id (existem IDs duplicados para os talhões)

# %%
df['field_id'].nunique()
# Out:
# 36234

# %%
df[df.duplicated('field_id')]
# Out:
#      monitoring_class     period state field_id  \
# 6131             RICE  2017/2018    TO     41_2
# 6135             RICE  2017/2018    TO     53_1
# 6137             RICE  2017/2018    TO     62_3
# 6151             RICE  2017/2018    TO     84_3
# 6152             RICE  2017/2018    TO     92_2
# ...               ...        ...   ...      ...
# 4805            WHEAT  2023/2023    PR     None
# 4806            WHEAT  2023/2023    PR     None
# 4807            WHEAT  2023/2023    PR     None
# 4808            WHEAT  2023/2023    PR     None
# 4809            WHEAT  2023/2023    PR     None
#
#                                       fonte          area  micro start_season  \
# 6131       Conab - Arroz Irrigado 2017/2018  3.053780e+05     59   2017-10-01
# 6135       Conab - Arroz Irrigado 2017/2018  5.749160e+05     60   2017-10-01
# 6137       Conab - Arroz Irrigado 2017/2018  3.274483e+06     60   2017-10-01
# 6151       Conab - Arroz Irrigado 2017/2018  5.458330e+05     60   2017-10-01
# 6152       Conab - Arroz Irrigado 2017/2018  1.406380e+06     60   2017-10-01
# ...                                     ...           ...    ...          ...
# 4805  Conab - Culturas de Inverno 2023/2023  6.909008e+04    450   2023-04-01
# 4806  Conab - Culturas de Inverno 2023/2023  1.002700e+05    450   2023-04-01
# 4807  Conab - Culturas de Inverno 2023/2023  3.415436e+05    450   2023-04-01
# 4808  Conab - Culturas de Inverno 2023/2023  7.230476e+04    450   2023-04-01
# 4809  Conab - Culturas de Inverno 2023/2023  1.417802e+05    450   2023-04-01
#
#      end_season peak_start  ...       start_of_cycle         end_of_cycle  \
# 6131 2018-06-01 2017-12-01  ...  2018-01-16 00:00:00  2018-05-21 00:00:00
# 6135 2018-06-01 2017-12-01  ...  2017-11-17 00:00:00  2018-03-02 00:00:00
# 6137 2018-06-01 2017-12-01  ...  2017-11-12 00:00:00  2018-02-20 00:00:00
# 6151 2018-06-01 2017-12-01  ...  2017-11-17 00:00:00  2018-04-11 00:00:00
# 6152 2018-06-01 2017-12-01  ...  2017-10-23 00:00:00  2018-02-07 00:00:00
# ...         ...        ...  ...                  ...                  ...
# 4805 2024-01-01 2023-06-01  ...           2023-04-04           2023-10-06
# 4806 2024-01-01 2023-06-01  ...           2023-04-04           2023-09-26
# 4807 2024-01-01 2023-06-01  ...           2023-05-04           2023-11-10
# 4808 2024-01-01 2023-06-01  ...           2023-04-04           2023-09-26
# 4809 2024-01-01 2023-06-01  ...           2023-04-04           2023-10-16
#
#      length_of_cycle      start_of_season        end_of_season  \
# 6131             125  2018-01-16 00:00:00  2018-05-13 00:00:00
# 6135             105  2017-10-24 00:00:00  2018-04-11 00:00:00
# 6137             100  2017-10-14 00:00:00  2018-02-13 00:00:00
# 6151             145  2017-11-24 00:00:00  2018-04-12 00:00:00
# 6152             107  2017-10-12 00:00:00  2018-04-06 00:00:00
# ...              ...                  ...                  ...
# 4805             185           2023-06-19           2023-10-01
# 4806             175           2023-05-21           2023-09-15
# 4807             190           2023-06-02           2023-10-29
# 4808             175           2023-05-09           2023-08-07
# 4809             195           2023-05-20           2023-10-10
#
#            peak_of_season length_of_season  \
# 6131  2018-02-15T00:00:00              117
# 6135  2018-01-21T00:00:00              169
# 6137  2018-01-01T00:00:00              122
# 6151  2018-02-10T00:00:00              139
# 6152  2018-01-16T00:00:00              176
# ...                   ...              ...
# 4805  2023-08-22 00:00:00              104
# 4806  2023-08-07 00:00:00              117
# 4807  2023-08-02 00:00:00              149
# 4808  2023-06-08 00:00:00               90
# 4809  2023-08-02 00:00:00              143
#
#                                         eopath_location  \
# 6131  start_2017-10-01_end_2018-06-01_monitoring_cla...
# 6135  start_2017-10-01_end_2018-06-01_monitoring_cla...
# 6137  start_2017-10-01_end_2018-06-01_monitoring_cla...
# 6151  start_2017-10-01_end_2018-06-01_monitoring_cla...
# 6152  start_2017-10-01_end_2018-06-01_monitoring_cla...
# ...                                                 ...
# 4805  start_2023-04-01_end_2024-01-01_monitoring_cla...
# 4806  start_2023-04-01_end_2024-01-01_monitoring_cla...
# 4807  start_2023-04-01_end_2024-01-01_monitoring_cla...
# 4808  start_2023-04-01_end_2024-01-01_monitoring_cla...
# 4809  start_2023-04-01_end_2024-01-01_monitoring_cla...
#
#                                                geometry dataset_part
# 6131  MULTIPOLYGON (((-49.88425 -10.47874, -49.88308...        train
# 6135  MULTIPOLYGON (((-49.55478 -10.83641, -49.55464...        train
# 6137  MULTIPOLYGON (((-49.50023 -11.15293, -49.50023...        train
# 6151  MULTIPOLYGON (((-49.57375 -10.87316, -49.57378...        train
# 6152  MULTIPOLYGON (((-49.32316 -11.17751, -49.32314...        train
# ...                                                 ...          ...
# 4805  MULTIPOLYGON (((-49.20935 -25.92179, -49.20935...         test
# 4806  MULTIPOLYGON (((-49.66929 -26.08043, -49.66929...         test
# 4807  MULTIPOLYGON (((-49.65025 -25.95826, -49.65007...         test
# 4808  MULTIPOLYGON (((-49.47238 -25.94766, -49.47256...         test
# 4809  MULTIPOLYGON (((-49.73037 -26.06138, -49.72948...         test
#
# [10407 rows x 21 columns]

# %%
df[df.duplicated('field_id')]['field_id'].unique()
# Out:
# array(['41_2', '53_1', '62_3', ..., '880_1', '884_1', '914_2'],
#       dtype=object)

# %%
df[df['field_id'].isin(['41_2'])]
# Out:
#       monitoring_class     period state field_id  \
# 5449            COTTON  2021/2022    BA     41_2
# 6131              RICE  2017/2018    TO     41_2
# 28896          SOYBEAN  2021/2022    RO     41_2
#
#                                        fonte        area  micro start_season  \
# 5449   Agrosatélite - Grãos Brasil 2021/2022   1963743.0    220   2021-11-01
# 6131        Conab - Arroz Irrigado 2017/2018    305378.0     59   2017-10-01
# 28896  Agrosatélite - Grãos Brasil 2021/2022  20267233.0      0   2021-10-01
#
#       end_season peak_start  ...       start_of_cycle         end_of_cycle  \
# 5449  2022-10-01 2022-02-01  ...  2022-01-09 00:00:00  2022-10-01 00:00:00
# 6131  2018-06-01 2017-12-01  ...  2018-01-16 00:00:00  2018-05-21 00:00:00
# 28896 2022-05-01 2021-12-01  ...  2021-10-12 00:00:00  2022-01-30 00:00:00
#
#       length_of_cycle      start_of_season        end_of_season  \
# 5449              265  2022-01-20 00:00:00  2022-07-23 00:00:00
# 6131              125  2018-01-16 00:00:00  2018-05-13 00:00:00
# 28896             110  2021-10-19 00:00:00  2022-03-01 00:00:00
#
#             peak_of_season length_of_season  \
# 5449   2022-04-24T00:00:00              184
# 6131   2018-02-15T00:00:00              117
# 28896  2021-12-01T00:00:00              133
#
#                                          eopath_location  \
# 5449   start_2021-11-01_end_2022-10-01_monitoring_cla...
# 6131   start_2017-10-01_end_2018-06-01_monitoring_cla...
# 28896  start_2021-10-01_end_2022-05-01_monitoring_cla...
#
#                                                 geometry dataset_part
# 5449   MULTIPOLYGON (((-46.16128 -12.77912, -46.16128...        train
# 6131   MULTIPOLYGON (((-49.88425 -10.47874, -49.88308...        train
# 28896  MULTIPOLYGON (((-62.82534 -9.44642, -62.82463 ...        train
#
# [3 rows x 21 columns]

# %% [markdown]
# ### 4.10 Analysis ``LOS`` and ``length_of_season``

# %%
df[['length_of_season', 'monitoring_class']]
# Out:
#       length_of_season monitoring_class
# 0                  156             CORN
# 1                  135             CORN
# 2                  120             CORN
# 3                  128             CORN
# 4                  123             CORN
# ...                ...              ...
# 4805               104            WHEAT
# 4806               117            WHEAT
# 4807               149            WHEAT
# 4808                90            WHEAT
# 4809               143            WHEAT
#
# [46642 rows x 2 columns]

# %%
df.groupby('monitoring_class').agg({'length_of_season':['max', 'mean','min']})
# Out:
#                  length_of_season
#                               max        mean  min
# monitoring_class
# CORN                          160  125.735552   60
# COTTON                        240  190.315436  120
# RICE                          180  136.597613   78
# SOYBEAN                       160  117.017122   61
# WHEAT                         150  117.731243   90

# %% [markdown]
# ## 5. Generating Html Report

# %%
from ydata_profiling import ProfileReport
from ydata_profiling.config import Settings
# %matplotlib inline

# %%
df_copy = df.drop(columns=['cultura_2', 'geometry'])  # Supondo que 'cultura_2' seja a coluna problemática

# %%
df_e_object = df_copy.select_dtypes(exclude=['object'])
df_e_object
# Out:
#              area  meso start_season end_season peak_start   peak_end  \
# 0      10269314.0   505   2021-10-01 2022-06-01 2021-12-01 2022-03-01
# 1      10269314.0   505   2021-10-01 2022-06-01 2021-12-01 2022-03-01
# 2      10269314.0   505   2021-10-01 2022-06-01 2021-12-01 2022-03-01
# 3      10269314.0   505   2021-10-01 2022-06-01 2021-12-01 2022-03-01
# 4      10269314.0   505   2021-10-01 2022-06-01 2021-12-01 2022-03-01
# ...           ...   ...          ...        ...        ...        ...
# 38187    681005.0   494   2019-09-01 2020-06-01 2019-11-01 2020-03-01
# 38188    681005.0   494   2019-09-01 2020-06-01 2019-11-01 2020-03-01
# 38189    139290.0   505   2019-09-01 2020-06-01 2019-11-01 2020-03-01
# 38190    176041.0   509   2018-08-01 2019-05-01 2018-10-01 2019-02-01
# 38191    664225.0   551   2018-10-01 2019-06-01 2018-12-01 2019-03-01
#
#        contour_score contour_selected_timestamp  compac_index planting_start  \
# 0           0.995002                 2022-03-03      2.559326     2021-10-01
# 1           0.995002                 2022-03-03      2.030404     2021-10-01
# 2           0.995002                 2022-03-03      1.498424     2021-10-01
# 3           0.995002                 2022-03-03      1.929409     2021-10-01
# 4           0.995002                 2022-03-03      1.476064     2021-10-01
# ...              ...                        ...           ...            ...
# 38187       0.990099                 2020-02-04      2.202441     2019-09-01
# 38188       0.990099                 2020-02-04      1.593055     2019-09-01
# 38189            NaN                 2020-01-18      1.903089     2019-09-01
# 38190       0.989781                 2019-01-22      1.452775     2018-08-01
# 38191       0.993689                 2019-04-05      1.743605     2018-10-01
#
#       planting_end cycle_start  cycle_end  LOS  is_valid_cvt start_of_season  \
# 0       2022-02-01  2021-12-03 2022-05-12  160          True      2021-12-14
# 1       2022-02-01  2021-11-23 2022-04-17  145          True      2021-12-10
# 2       2022-02-01  2021-12-03 2022-04-22  140          True      2021-12-12
# 3       2022-02-01  2021-12-03 2022-05-02  150          True      2021-12-11
# 4       2022-02-01  2021-12-03 2022-04-17  135          True      2021-12-16
# ...            ...         ...        ...  ...           ...             ...
# 38187   2020-01-01  2019-09-27 2020-05-29  245          True      2019-10-25
# 38188   2020-01-01  2019-10-07 2020-05-19  225          True      2019-10-16
# 38189   2020-01-01  2019-11-04 2020-05-27  205          True      2019-11-11
# 38190   2019-01-01  2018-08-20 2019-03-08  200          True      2018-10-29
# 38191   2019-01-01  2018-10-17 2019-02-04  110         False      2018-10-17
#
#       end_of_season      peaks  length_of_season
# 0        2022-05-03 2022-02-26               140
# 1        2022-05-03 2022-02-26               144
# 2        2022-05-03 2022-02-26               142
# 3        2022-04-15 2022-02-26               125
# 4        2022-04-14 2022-02-26               119
# ...             ...        ...               ...
# 38187    2020-03-26 2020-01-25               153
# 38188    2020-03-12 2020-01-05               148
# 38189    2020-03-26 2020-01-18               136
# 38190    2019-03-01 2019-01-22               123
# 38191    2019-01-20 2018-12-21                95
#
# [38192 rows x 19 columns]

# %%
df_i_object = df_copy.select_dtypes(include=['object'])
df_i_object
# Out:
#       monitoring_class     period                                  fonte  \
# 0              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 1              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 2              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 3              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 4              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# ...                ...        ...                                    ...
# 38187             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 38188             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 38189             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 38190             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
# 38191             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
#
#       state obs_extra                                    eopath_location  \
# 0        RS            start_2021-10-01_end_2022-06-01_monitoring_cla...
# 1        RS            start_2021-10-01_end_2022-06-01_monitoring_cla...
# 2        RS            start_2021-10-01_end_2022-06-01_monitoring_cla...
# 3        RS            start_2021-10-01_end_2022-06-01_monitoring_cla...
# 4        RS            start_2021-10-01_end_2022-06-01_monitoring_cla...
# ...     ...       ...                                                ...
# 38187    RS            start_2019-09-01_end_2020-06-01_monitoring_cla...
# 38188    RS            start_2019-09-01_end_2020-06-01_monitoring_cla...
# 38189    RS            start_2019-09-01_end_2020-06-01_monitoring_cla...
# 38190    MS            start_2018-08-01_end_2019-06-01_monitoring_cla...
# 38191    GO            start_2018-10-01_end_2019-06-01_monitoring_cla...
#
#                                 sentinel_eopatch_current field_id is_valid
# 0      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_0        1
# 1      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_1        1
# 2      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_2        1
# 3      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_6        1
# 4      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_8        1
# ...                                                  ...      ...      ...
# 38187  start_2019-09-01_end_2020-06-01_monitoring_cla...     52_0        0
# 38188  start_2019-09-01_end_2020-06-01_monitoring_cla...     52_2        0
# 38189  start_2019-09-01_end_2020-06-01_monitoring_cla...     80_2        0
# 38190  start_2018-08-01_end_2019-06-01_monitoring_cla...     81_0        0
# 38191  start_2018-10-01_end_2019-06-01_monitoring_cla...    101_5        1
#
# [38192 rows x 9 columns]

# %%
df_e_object_colums = df_copy.select_dtypes(exclude=['object']).columns

# %%
title = "data_report_07_10_2024_full_copy_v3"
config = Settings()
config.vars.cat.words = False  # Desativa a nuvem de palavras
report  = ProfileReport(df=df_copy[list(df_e_object_colums) + ['monitoring_class', 'state', 'period', 'fonte']], 
                        title=title,
                        minimal=False,
                        config=config)

report.to_file(f'{title}.html')
# Out:
# /home/ec2-user/.local/lib/python3.10/site-packages/ydata_profiling/utils/dataframe.py:137: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"index": "df_index"}, inplace=True)
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df_number = df.select_dtypes(exclude=['float','int', 'datetime'])
df_number
# Out:
#       monitoring_class     period                                  fonte  \
# 0              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 1              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 2              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 3              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# 4              SOYBEAN  2021/2022  Agrosatélite - Grãos Brasil 2021/2022
# ...                ...        ...                                    ...
# 38187             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 38188             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 38189             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 38190             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
# 38191             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
#
#       cultura_2 state obs_extra  \
# 0          None    RS
# 1          None    RS
# 2          None    RS
# 3          None    RS
# 4          None    RS
# ...         ...   ...       ...
# 38187      None    RS
# 38188      None    RS
# 38189      None    RS
# 38190      None    MS
# 38191      None    GO
#
#                                          eopath_location  \
# 0      start_2021-10-01_end_2022-06-01_monitoring_cla...
# 1      start_2021-10-01_end_2022-06-01_monitoring_cla...
# 2      start_2021-10-01_end_2022-06-01_monitoring_cla...
# 3      start_2021-10-01_end_2022-06-01_monitoring_cla...
# 4      start_2021-10-01_end_2022-06-01_monitoring_cla...
# ...                                                  ...
# 38187  start_2019-09-01_end_2020-06-01_monitoring_cla...
# 38188  start_2019-09-01_end_2020-06-01_monitoring_cla...
# 38189  start_2019-09-01_end_2020-06-01_monitoring_cla...
# 38190  start_2018-08-01_end_2019-06-01_monitoring_cla...
# 38191  start_2018-10-01_end_2019-06-01_monitoring_cla...
#
#                                 sentinel_eopatch_current field_id is_valid  \
# 0      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_0        1
# 1      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_1        1
# 2      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_2        1
# 3      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_6        1
# 4      start_2021-10-01_end_2022-06-01_monitoring_cla...  13415_8        1
# ...                                                  ...      ...      ...
# 38187  start_2019-09-01_end_2020-06-01_monitoring_cla...     52_0        0
# 38188  start_2019-09-01_end_2020-06-01_monitoring_cla...     52_2        0
# 38189  start_2019-09-01_end_2020-06-01_monitoring_cla...     80_2        0
# 38190  start_2018-08-01_end_2019-06-01_monitoring_cla...     81_0        0
# 38191  start_2018-10-01_end_2019-06-01_monitoring_cla...    101_5        1
#
#        is_valid_cvt                                           geometry
# 0              True  POLYGON ((-52.44675 -32.21676, -52.44679 -32.2...
# 1              True  POLYGON ((-52.44533 -32.21992, -52.44368 -32.2...
# 2              True  POLYGON ((-52.45559 -32.21991, -52.45526 -32.2...
# 3              True  POLYGON ((-52.46623 -32.22236, -52.46621 -32.2...
# 4              True  POLYGON ((-52.45816 -32.22394, -52.45805 -32.2...
# ...             ...                                                ...
# 38187          True  POLYGON ((-50.64755 -29.66027, -50.64755 -29.6...
# 38188          True  POLYGON ((-50.64708 -29.66136, -50.64704 -29.6...
# 38189          True  POLYGON ((-52.75066 -32.89058, -52.75065 -32.8...
# 38190          True  POLYGON ((-56.70471 -20.11537, -56.70492 -20.1...
# 38191         False  POLYGON ((-47.03444 -14.51352, -47.03449 -14.5...
#
# [38192 rows x 12 columns]

# %% [markdown]
# # 5. Analysis culture per state

# %%
df[df['state'].isin(['BA', 'RS', 'MT'])].groupby('state').agg({'monitoring_class':'value_counts'})
# Out:
#                         monitoring_class
# state monitoring_class
# BA    SOYBEAN                        561
#       COTTON                         383
#       CORN                           249
# MT    SOYBEAN                       4546
#       COTTON                         798
#       CORN                           365
# RS    SOYBEAN                       2239
#       RICE                           595
#       CORN                           504

# %%
df[df['state'].isin(['BA'])].to_file("/agrilearn_app/datasets/geopackages/crop-classification-v3-bahia", driver='GPKG', engine='fiona')
df[df['state'].isin(['RS'])].to_file("/agrilearn_app/datasets/geopackages/crop-classification-v3-rio-grande-do-sul", driver='GPKG', engine='fiona')
df[df['state'].isin(['MT'])].to_file("/agrilearn_app/datasets/geopackages/crop-classification-v3-mato-grosso", driver='GPKG', engine='fiona')
