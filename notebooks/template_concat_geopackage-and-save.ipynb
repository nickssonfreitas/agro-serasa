# %%
import boto3
import geopandas as gpd
from io import BytesIO
import pandas as pd
from folium import GeoJson
import folium
import numpy as np
from agrilearn.crop_classification import s3_utils, str_utils, eopatch_utils
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_323383/1592821757.py in <cell line: 8>()
#       6 import folium
#       7 import numpy as np
# ----> 8 from agrilearn.crop_classification import s3_utils, str_utils, eopatch_utils
#
# /agrilearn_app/agrilearn/submodules/crop_rnn/agrilearn/crop_classification/__init__.py in <module>
#       1 """Init imports"""
# ----> 2 from .cropclassifier import CropClassifier
#       3 from .evaluate_utils import *
#
# /agrilearn_app/agrilearn/submodules/crop_rnn/agrilearn/crop_classification/cropclassifier.py in <module>
#      18 import numpy as np
#      19 import pandas as pd
# ---> 20 from agrilearn.commons.exceptions import LowNDVIValue
#      21 from agrilearn.commons.scores.entropy_score import get_score
#      22 from agrilearn.commons.utils.date_utils import check_and_format_date
#
# ModuleNotFoundError: No module named 'agrilearn.commons'

# %%
import sys
sys.path.append("/agrilearn_app/agrilearn/")

# %% [markdown]
# ## 1. Define Dataset Path

# %%
DATASET_PATH_1 = '/agrilearn_app/datasets/teste_pre_safra_2024_2025/geopackage/processed/250111_data_merged_crop_120_06_08_2024_input_mvp.gpkg'
DATASET_PATH_2 = "/agrilearn_app/datasets/base/geopackage/processed/CORN_73080_SOYBEAN_29670_COTTON_1632_RICE_1172.gpkg"

# %% [markdown]
# ## 2. Read and Concat

# %%
df_1 = gpd.read_file(DATASET_PATH_1)

# %%
df_1['dataset_part'].value_counts()
# Out:
# dataset_part
# test    8347
# Name: count, dtype: int64

# %%
df_1['gt_class'].value_counts()
# Out:
# gt_class
# SOYBEAN       7270
# CORN           579
# COTTON         267
# RICE            81
# PASTURE         50
# SUGAR_CANE      50
# WHEAT           50
# Name: count, dtype: int64

# %%
df_1['monitoring_class'] = df_1['gt_class']

# %%
df_1.columns
# Out:
# Index(['interest_area_id', 'period', 'start_season', 'emergence_date',
#        'gt_class', 'end_season', 'monitoring_class', 'state', 'peak_start',
#        'peak_end', 'sentinel_eopatch_current', 'obs_contour',
#        'obs_contour_score', 'agricultural_area', 'obs_farm_plot',
#        'obs_emergence', 'obs_senescence', 'obs_harvest', 'obs_extra',
#        'created_by', 'area_id', 'last_date_crop_rnn',
#        'crop_distance_score_sits', 'crop_confidence_maha_sits', 'set',
#        'eopath_location', 'dataset_part', 'start_of_season', 'peak_of_season',
#        'end_of_season', 'length_of_season', 'is_valid_metrics', 'sos_valid',
#        'pos_valid', 'eos_valid', 'los_valid', 'geometry'],
#       dtype='object')

# %%
df_2 = gpd.read_file(DATASET_PATH_2)

# %%
df_2 = df_2[(df_2['monitoring_class'] == 'CORN') & (
    df_2['dataset_part'] == 'test') & (df_2['period'] == '2023/2023')]

# %%
# Concatenar os GeoDataFrames
df = pd.concat([df_1, df_2], ignore_index=True)

# %%
df
# Out:
#        interest_area_id     period start_season emergence_date gt_class  \
# 0                   0.0  2023/2024   2023-10-01     2024-01-12  SOYBEAN
# 1                   1.0  2023/2024   2023-10-01     2024-01-12  SOYBEAN
# 2                   2.0  2023/2024   2023-10-01     2023-12-06  SOYBEAN
# 3                   3.0  2023/2024   2023-10-01     2024-01-17  SOYBEAN
# 4                   4.0  2023/2024   2023-10-01     2024-01-17  SOYBEAN
# ...                 ...        ...          ...            ...      ...
# 13299               NaN  2023/2023   2023-02-01            NaN      NaN
# 13300               NaN  2023/2023   2023-02-01            NaN      NaN
# 13301               NaN  2023/2023   2023-02-01            NaN      NaN
# 13302               NaN  2023/2023   2023-02-01            NaN      NaN
# 13303               NaN  2023/2023   2023-02-01            NaN      NaN
#
#       end_season monitoring_class state peak_start   peak_end  ...  \
# 0     2024-05-01          SOYBEAN    GO 2023-12-01 2024-02-01  ...
# 1     2024-05-01          SOYBEAN    GO 2023-12-01 2024-02-01  ...
# 2     2024-09-01          SOYBEAN    PA 2023-12-01 2024-06-01  ...
# 3     2024-05-01          SOYBEAN    GO 2023-12-01 2024-02-01  ...
# 4     2024-05-01          SOYBEAN    GO 2023-12-01 2024-02-01  ...
# ...          ...              ...   ...        ...        ...  ...
# 13299 2023-10-01             CORN    DF 2023-04-01 2023-07-01  ...
# 13300 2023-10-01             CORN    DF 2023-04-01 2023-07-01  ...
# 13301 2023-10-01             CORN    DF 2023-04-01 2023-07-01  ...
# 13302 2023-10-01             CORN    DF 2023-04-01 2023-07-01  ...
# 13303 2023-10-01             CORN    DF 2023-04-01 2023-07-01  ...
#
#       compac_index key_bucket local_eopatch_path total_imagens_do_intervalo  \
# 0              NaN        NaN                NaN                        NaN
# 1              NaN        NaN                NaN                        NaN
# 2              NaN        NaN                NaN                        NaN
# 3              NaN        NaN                NaN                        NaN
# 4              NaN        NaN                NaN                        NaN
# ...            ...        ...                ...                        ...
# 13299          NaN       None               None                       None
# 13300          NaN       None               None                       None
# 13301          NaN       None               None                       None
# 13302          NaN       None               None                       None
# 13303          NaN       None               None                       None
#
#       total_de_imagem status_missing_images days_gap dates_diff  \
# 0                 NaN                   NaN      NaN        NaN
# 1                 NaN                   NaN      NaN        NaN
# 2                 NaN                   NaN      NaN        NaN
# 3                 NaN                   NaN      NaN        NaN
# 4                 NaN                   NaN      NaN        NaN
# ...               ...                   ...      ...        ...
# 13299            None                  None     None       None
# 13300            None                  None     None       None
# 13301            None                  None     None       None
# 13302            None                  None     None       None
# 13303            None                  None     None       None
#
#       mean_dates_diff status_series_missing
# 0                 NaN                   NaN
# 1                 NaN                   NaN
# 2                 NaN                   NaN
# 3                 NaN                   NaN
# 4                 NaN                   NaN
# ...               ...                   ...
# 13299             NaN                  None
# 13300             NaN                  None
# 13301             NaN                  None
# 13302             NaN                  None
# 13303             NaN                  None
#
# [13304 rows x 70 columns]

# %%
value_counts = df['monitoring_class'].value_counts()
filename = '_'.join(
    [f"{cls}_{count}" for cls, count in value_counts.items()]) + ".gpkg"
filename
# Out:
# 'SOYBEAN_7270_CORN_5536_COTTON_267_RICE_81_PASTURE_50_SUGAR_CANE_50_WHEAT_50.gpkg'

# %%
OUTPUT_DATASET_FINAL = f"/agrilearn_app/datasets/teste_pre_safra_2024_2025/geopackage/processed/{filename}"

# %%
df.to_file(OUTPUT_DATASET_FINAL, driver='GPKG', engine='fiona')

# %% [markdown]
# ## 3. Adjusting features

# %%
# replacement_dict = {
#     'SUGAR_CANE': 'cana',
#     'SOYBEAN': 'soybean',
#     'CORN': 'corn',
#     'COTTON': 'cotton',
#     'RICE': 'rice'
# }

# df['monitoring_class_path'] = df['monitoring_class'].replace(replacement_dict)

# %%
# eopatch_utils.create_local_eopatch_path(df, 
#                           path_local="/agrilearn_app/datasets/eopatchs/processed",
#                           label_monitoring_class='monitoring_class_path',
#                           label_dataset_part='dataset_part',
#                           label_eopatch_location='eopath_location',
#                           )

# %%
df.isna().sum()
# Out:
# monitoring_class                  0
# period                            0
# fonte                             0
# cultura_2                     38192
# state                             0
# area                              0
# meso                              0
# obs_extra                         0
# eopath_location                   0
# start_season                      0
# end_season                        0
# peak_start                        0
# peak_end                          0
# sentinel_eopatch_current          0
# contour_score                  2997
# contour_selected_timestamp        0
# field_id                          0
# compac_index                      0
# planting_start                35276
# planting_end                  35276
# cycle_start                   35276
# cycle_end                     35276
# LOS                           35276
# is_valid                      35276
# is_valid_cvt                  35276
# start_of_season               35276
# end_of_season                 35276
# peaks                         35276
# length_of_season              35276
# key_bucket                    35276
# dataset_part                      0
# local_eopatch_path                0
# total_imagens_do_intervalo    35276
# total_de_imagem               35276
# status_missing_images         35276
# days_gap                      73468
# dates_diff                    73468
# mean_dates_diff               35276
# status_series_missing         35276
# geometry                          0
# monitoring_class_path             0
# dtype: int64
