# %%
import boto3
import geopandas as gpd
import pandas as pd
import folium
import numpy as np
from folium import GeoJson
from io import BytesIO

# %%
import sys
sys.path.append("/agrilearn_app/agrilearn/")
from agrilearn.crop_classification import s3_utils, str_utils
from agrilearn.crop_classification import evaluate_utils as eval_util
from agrilearn.crop_classification import yaml_utils, processing
# Out:
# 2025-01-15 18:18:31.661889: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-01-15 18:18:31.679674: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1736965111.699630   11347 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1736965111.705805   11347 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-15 18:18:31.727060: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Global Variables

# %%
config = yaml_utils.load_config("/agrilearn_app/output/experiment/experiment_10.yaml")

# %%
GEOPACKAGE_PATH = config['data']['geopackage_train_data_path']
label_monitoring_class = 'monitoring_class'
label_eopatch_path = "eopath_location" # 'sentinel_eopatch_current' #eopath_location

# %% [markdown]
# # 1. Read Datasets
#
# ### Data description
# - monitoring_class: é a cultura de interesse dp cliente ou da amostra de treinamento (SOYBEAN, CORN)
# - period:  a safra agricola (2023/2024, 2024/2025)
# - state: é o estado do polígono
# - field_id: id do talhão
# - fonte: a origem dos dados (mapas temáticos, banco de dados)
# - area:
# - micro:
# - start_season: é a data que inicia a safra pra determinada cultura (monitoring_class) e safra (period)
# - end_season: é a data que termina a safra pra determinada cultura (monitoring_class) e safra (period)
# - peak_start: é a data que inicia o período em que pode ocorrer o pico pra determinada cultura (monitoring_class) e safra (period)
# - peak_end: é a data que termina o período em que pode ocorrer o pico pra determinada cultura (monitoring_class) e safra (period) (Obs: temos um calendário pra isso, um arquivo yaml)
# - start_of_cycle: data do inio do cultivo segundo o calendário agrícola
# - end_of_cycle: data do fim do caledário de cuiltivo segundo calendário agrícola
# - length_of_cycle:
# - start_of_season: data da emergencia da cultura
# - end_of_season: data da colheita da cultura
# - peak_of_season: data do pico vegetativo da cultura
# - length_of_season: Duração do cultivo
# - eopath_location: é caminho onde o eopatch está salvo (imagens p/ inferência)
# - geometry: é a geometria do polígono]

# %%
df = gpd.read_file(GEOPACKAGE_PATH)

# %%
df['monitoring_class'].value_counts()
# Out:
# monitoring_class
# SOYBEAN    29670
# CORN       14600
# COTTON      1619
# RICE        1172
# Name: count, dtype: int64

# %%
df['state'].value_counts()
# Out:
# state
# PR    7035
# MT    6641
# MG    6110
# SP    5871
# RS    4154
# GO    4051
# MS    2801
# MA    1887
# TO    1867
# RO    1357
# SC    1220
# BA    1202
# PA    1202
# PI    1164
# RR     275
# DF     185
# AP      39
# Name: count, dtype: int64

# %%
print(f"There are {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# There are 47061 rows and 54 columns

# %%
print(f"Dados de {df['start_season'].min()} a {df['end_season'].max()}")
# Out:
# Dados de 2017-09-01 00:00:00 a 2024-09-01 00:00:00

# %%
list(df.columns)
# Out:
# ['monitoring_class',
#  'period',
#  'fonte',
#  'state',
#  'area',
#  'meso',
#  'eopath_location',
#  'start_season',
#  'end_season',
#  'peak_start',
#  'peak_end',
#  'field_id',
#  'planting_start',
#  'planting_end',
#  'cycle_start',
#  'cycle_end',
#  'LOS',
#  'is_valid',
#  'is_valid_cvt',
#  'start_of_season',
#  'end_of_season',
#  'peaks',
#  'length_of_season',
#  'set_type',
#  'sampled_date',
#  'micro',
#  'peak_of_season',
#  'is_valid_metrics',
#  'sos_valid',
#  'pos_valid',
#  'eos_valid',
#  'los_valid',
#  'start_of_cycle',
#  'end_of_cycle',
#  'length_of_cycle',
#  'is_valid_POS',
#  'is_valid_LOS',
#  'dataset_part',
#  'cultura_2',
#  'obs_extra',
#  'sentinel_eopatch_current',
#  'contour_score',
#  'contour_selected_timestamp',
#  'compac_index',
#  'key_bucket',
#  'local_eopatch_path',
#  'total_imagens_do_intervalo',
#  'total_de_imagem',
#  'status_missing_images',
#  'days_gap',
#  'dates_diff',
#  'mean_dates_diff',
#  'status_series_missing',
#  'geometry']

# %%
df['dataset_part'].value_counts(normalize=True)*100
# Out:
# dataset_part
# train    69.979388
# test     15.020930
# val      14.999681
# Name: proportion, dtype: float64

# %% [markdown]
# # 2. Data Processing

# %% [markdown]
# ### 2.1 Check NaN Values

# %%
df.isna().sum()
# Out:
# monitoring_class                  0
# period                            0
# fonte                             0
# state                             0
# area                              0
# meso                          12378
# eopath_location                   0
# start_season                      0
# end_season                        0
# peak_start                        0
# peak_end                          0
# field_id                      12378
# planting_start                    0
# planting_end                      0
# cycle_start                   12378
# cycle_end                     12378
# LOS                           12378
# is_valid                          0
# is_valid_cvt                  12378
# start_of_season                   0
# end_of_season                     0
# peaks                         12378
# length_of_season                  0
# set_type                      33483
# sampled_date                  33483
# micro                         34683
# peak_of_season                34683
# is_valid_metrics              34683
# sos_valid                     34683
# pos_valid                     34683
# eos_valid                     34683
# los_valid                     34683
# start_of_cycle                34687
# end_of_cycle                  34687
# length_of_cycle               34687
# is_valid_POS                  34683
# is_valid_LOS                  34683
# dataset_part                      0
# cultura_2                     47061
# obs_extra                     13578
# sentinel_eopatch_current      13578
# contour_score                 14576
# contour_selected_timestamp    13578
# compac_index                  13578
# key_bucket                    13578
# local_eopatch_path            13578
# total_imagens_do_intervalo    13578
# total_de_imagem               13578
# status_missing_images         13578
# days_gap                      47061
# dates_diff                    47061
# mean_dates_diff               13578
# status_series_missing         13578
# geometry                          0
# dtype: int64

# %% [markdown]
# ### 2.2 Check Duplicated

# %%
shape_before = df.shape[0]
idx_drop_duplicated = df[df.duplicated(subset=['period', 'geometry'])].index
df.drop(idx_drop_duplicated, inplace=True)
shape_after = df.shape[0]
print(f"{shape_before-shape_after} registros duplicados foram encontrados")
# Out:
# 0 registros duplicados foram encontrados

# %% [markdown]
# ### 2.3 Data Formatation

# %%
df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 47061 entries, 0 to 47060
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   monitoring_class            47061 non-null  object
#  1   period                      47061 non-null  object
#  2   fonte                       47061 non-null  object
#  3   state                       47061 non-null  object
#  4   area                        47061 non-null  float64
#  5   meso                        34683 non-null  float64
#  6   eopath_location             47061 non-null  object
#  7   start_season                47061 non-null  datetime64[ms]
#  8   end_season                  47061 non-null  datetime64[ms]
#  9   peak_start                  47061 non-null  datetime64[ms]
#  10  peak_end                    47061 non-null  datetime64[ms]
#  11  field_id                    34683 non-null  object
#  12  planting_start              47061 non-null  object
#  13  planting_end                47061 non-null  object
#  14  cycle_start                 34683 non-null  datetime64[ms]
#  15  cycle_end                   34683 non-null  datetime64[ms]
#  16  LOS                         34683 non-null  object
#  17  is_valid                    47061 non-null  object
#  18  is_valid_cvt                34683 non-null  float64
#  19  start_of_season             47061 non-null  object
#  20  end_of_season               47061 non-null  object
#  21  peaks                       34683 non-null  object
#  22  length_of_season            47061 non-null  object
#  23  set_type                    13578 non-null  object
#  24  sampled_date                13578 non-null  object
#  25  micro                       12378 non-null  float64
#  26  peak_of_season              12378 non-null  object
#  27  is_valid_metrics            12378 non-null  object
#  28  sos_valid                   12378 non-null  object
#  29  pos_valid                   12378 non-null  object
#  30  eos_valid                   12378 non-null  object
#  31  los_valid                   12378 non-null  object
#  32  start_of_cycle              12374 non-null  object
#  33  end_of_cycle                12374 non-null  object
#  34  length_of_cycle             12374 non-null  object
#  35  is_valid_POS                12378 non-null  object
#  36  is_valid_LOS                12378 non-null  object
#  37  dataset_part                47061 non-null  object
#  38  cultura_2                   0 non-null      object
#  39  obs_extra                   33483 non-null  object
#  40  sentinel_eopatch_current    33483 non-null  object
#  41  contour_score               32485 non-null  float64
#  42  contour_selected_timestamp  33483 non-null  object
#  43  compac_index                33483 non-null  float64
#  44  key_bucket                  33483 non-null  object
#  45  local_eopatch_path          33483 non-null  object
#  46  total_imagens_do_intervalo  33483 non-null  object
#  47  total_de_imagem             33483 non-null  object
#  48  status_missing_images       33483 non-null  object
#  49  days_gap                    0 non-null      object
#  50  dates_diff                  0 non-null      object
#  51  mean_dates_diff             33483 non-null  float64
#  52  status_series_missing       33483 non-null  object
#  53  geometry                    47061 non-null  geometry
# dtypes: datetime64[ms](6), float64(7), geometry(1), object(40)
# memory usage: 19.4+ MB

# %%
datetime_columns = ['start_season', 
                    'end_season', 
                    'peak_start', 
                    'peak_end']

for col in datetime_columns:
    df[col] = pd.to_datetime(df[col])

df[datetime_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47061 entries, 0 to 47060
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   start_season  47061 non-null  datetime64[ms]
#  1   end_season    47061 non-null  datetime64[ms]
#  2   peak_start    47061 non-null  datetime64[ms]
#  3   peak_end      47061 non-null  datetime64[ms]
# dtypes: datetime64[ms](4)
# memory usage: 1.4 MB

# %% [markdown]
# ### 2.4 Vamos manter os dados nulos no campo ``contour_score``

# %%
df[df['contour_score'].isna()]
# Out:
#       monitoring_class     period                                  fonte  \
# 0                 CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 4                 CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 5                 CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 10                CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 11                CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# ...                ...        ...                                    ...
# 47011             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
# 47034             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 47050             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
# 47051             RICE  2018/2019       Conab - Arroz Irrigado 2018/2019
# 47058             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
#
#       state       area   meso  \
# 0        BA  7477129.0  222.0
# 4        BA  8072990.0  220.0
# 5        BA   953564.0  220.0
# 10       BA  1702437.0  222.0
# 11       BA  7536828.0  220.0
# ...     ...        ...    ...
# 47011    SC  1918965.0  469.0
# 47034    RS   714262.0  505.0
# 47050    SC  1918965.0  469.0
# 47051    SC  1918965.0  469.0
# 47058    RS   139290.0  505.0
#
#                                          eopath_location start_season  \
# 0      start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 4      start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 5      start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 10     start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 11     start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# ...                                                  ...          ...
# 47011  start_2018-09-01_end_2019-06-01_monitoring_cla...   2018-09-01
# 47034  start_2019-09-01_end_2020-06-01_monitoring_cla...   2019-09-01
# 47050  start_2018-09-01_end_2019-06-01_monitoring_cla...   2018-09-01
# 47051  start_2018-09-01_end_2019-06-01_monitoring_cla...   2018-09-01
# 47058  start_2019-09-01_end_2020-06-01_monitoring_cla...   2019-09-01
#
#       end_season peak_start  ...  \
# 0     2021-07-01 2021-01-01  ...
# 4     2021-07-01 2021-01-01  ...
# 5     2021-07-01 2021-01-01  ...
# 10    2021-07-01 2021-01-01  ...
# 11    2021-07-01 2021-01-01  ...
# ...          ...        ...  ...
# 47011 2019-06-01 2018-11-01  ...
# 47034 2020-06-01 2019-11-01  ...
# 47050 2019-06-01 2018-11-01  ...
# 47051 2019-06-01 2018-11-01  ...
# 47058 2020-06-01 2019-11-01  ...
#
#                                            key_bucket  \
# 0                                                None
# 4                                                None
# 5                                                None
# 10                                               None
# 11                                               None
# ...                                               ...
# 47011  datasets/culture/culture_v02/rice_test_v2.gpkg
# 47034  datasets/culture/culture_v02/rice_test_v2.gpkg
# 47050  datasets/culture/culture_v02/rice_test_v2.gpkg
# 47051  datasets/culture/culture_v02/rice_test_v2.gpkg
# 47058  datasets/culture/culture_v02/rice_test_v2.gpkg
#
#                                       local_eopatch_path  \
# 0                                                   None
# 4                                                   None
# 5                                                   None
# 10                                                  None
# 11                                                  None
# ...                                                  ...
# 47011  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47034  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47050  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47051  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47058  /agrilearn_app/datasets/eopatchs/processed/SOY...
#
#       total_imagens_do_intervalo total_de_imagem status_missing_images  \
# 0                           None            None                  None
# 4                           None            None                  None
# 5                           None            None                  None
# 10                          None            None                  None
# 11                          None            None                  None
# ...                          ...             ...                   ...
# 47011                         55              35                    OK
# 47034                         68              34                    OK
# 47050                         43              30                    OK
# 47051                         43              36                    OK
# 47058                         43              28                    OK
#
#       days_gap dates_diff mean_dates_diff  status_series_missing  \
# 0         None       None             NaN                   None
# 4         None       None             NaN                   None
# 5         None       None             NaN                   None
# 10        None       None             NaN                   None
# 11        None       None             NaN                   None
# ...        ...        ...             ...                    ...
# 47011     None       None            5.44                     OK
# 47034     None       None            5.15                     OK
# 47050     None       None            5.69                     OK
# 47051     None       None            5.57                     OK
# 47058     None       None            5.00                     OK
#
#                                                 geometry
# 0      MULTIPOLYGON (((-45.7944 -14.74452, -45.79466 ...
# 4      MULTIPOLYGON (((-45.97327 -13.19431, -45.97295...
# 5      MULTIPOLYGON (((-46.23854 -11.65442, -46.23862...
# 10     MULTIPOLYGON (((-45.8026 -13.4712, -45.8026 -1...
# 11     MULTIPOLYGON (((-46.12814 -12.56927, -46.12266...
# ...                                                  ...
# 47011  POLYGON ((-49.5122 -28.69859, -49.51208 -28.69...
# 47034  POLYGON ((-52.55275 -32.29614, -52.55275 -32.2...
# 47050  POLYGON ((-49.51818 -28.68918, -49.51812 -28.6...
# 47051  POLYGON ((-49.52119 -28.70226, -49.52169 -28.7...
# 47058  POLYGON ((-52.75066 -32.89058, -52.75065 -32.8...
#
# [14576 rows x 54 columns]

# %%
df[df['contour_score'].isna()].shape[0] / df.shape[0]
# Out:
# 0.3097256751875226

# %%
df[df['contour_score'].isna()]['monitoring_class'].value_counts()
# Out:
# monitoring_class
# CORN       13628
# SOYBEAN      825
# RICE          79
# COTTON        44
# Name: count, dtype: int64

# %% [markdown]
# ### 2.5 Drop data out cicle

# %%
drop_data = processing.filter_data_from_culture_cycle(df,
                                          label_monitoring_class='monitoring_class',
                                          label_los='LOS',
                                          culture_cycles={
                                               'COTTON': (140, 220),
                                               'CORN': (105, 160),
                                               'SOYBEAN': (90, 160),
                                               'WHEAT': (100, 160),
                                               'RICE': (100, 150),
                                               'BEAN': (60, 100),
                                               'SUGAR_CANE': (300, 570)
                                          })
# Out:
# Dados deletados: 5369
# Porcentagem de dados deletados: 11.41%

# %%
drop_data['monitoring_class'].value_counts()
# Out:
# monitoring_class
# SOYBEAN    2739
# COTTON     1238
# RICE        730
# CORN        662
# Name: count, dtype: int64

# %%
GEOPACKAGE_PATH
# Out:
# '/agrilearn_app/datasets/base/geopackage/processed/SOYBEAN_29670_CORN_14600_COTTON_1619_RICE_1172.gpkg'

# %%
# df.to_file("/agrilearn_app/datasets/base/geopackage/processed/SOYBEAN_29670_CORN_21919_COTTON_1619_RICE_1172_clear_cicle.gpkg", driver='GPKG', engine='fiona')

# %%
df['dataset_part']
# Out:
# 0        train
# 1         test
# 4        train
# 5        train
# 6          val
#          ...
# 47037    train
# 47038    train
# 47039    train
# 47047     test
# 47060    train
# Name: dataset_part, Length: 41692, dtype: object

# %% [markdown]
# # 3. Data Analysis

# %% [markdown]
# ### 4.1 Analysing Target y (monitoring_class)

# %%
pd.concat([df['monitoring_class'].value_counts(),
          df['monitoring_class'].value_counts(normalize=True)*100], axis=1)
# Out:
#                   count  proportion
# monitoring_class
# SOYBEAN           26931   64.595126
# CORN              13938   33.430874
# RICE                442    1.060155
# COTTON              381    0.913844

# %% [markdown]
# ### 5.2 Analysing fonte de dados

# %%
pd.concat([df['fonte'].value_counts(), 
           df['fonte'].value_counts(normalize=True)*100], axis=1)
# Out:
#                                                    count  proportion
# fonte
# Agrosatélite - Grãos Brasil 2021/2022              15029   36.047683
# Agrosatélite - Grãos Brasil 2020/2021              13843   33.203013
# Agrosatélite - Grãos 2022/2023                      6611   15.856759
# Agrosatélite - Grãos Sul 2022/2023                  2960    7.099683
# Agrosatélite - Grãos Amazonia e Cerrado 2022/2023   2807    6.732707
# Conab - Arroz Irrigado 2019/2020                     181    0.434136
# Conab - Arroz Irrigado 2018/2019                     144    0.345390
# Conab - Arroz Irrigado 2017/2018                      89    0.213470
# Conab - Arroz Irrigado 2021/2022                      28    0.067159

# %% [markdown]
# ### 5.3 Analysing dados por estado e classes

# %%
pd.concat([df['state'].value_counts(),
          df['state'].value_counts(normalize=True)*100], axis=1)
# Out:
#        count  proportion
# state
# PR      6339   15.204356
# MT      5834   13.993092
# MG      5577   13.376667
# SP      5211   12.498801
# GO      3817    9.155234
# RS      3293    7.898398
# MS      2648    6.351338
# TO      1728    4.144680
# MA      1658    3.976782
# RO      1308    3.137293
# PA      1138    2.729540
# SC       988    2.369759
# PI       986    2.364962
# BA       722    1.731747
# RR       238    0.570853
# DF       177    0.424542
# AP        30    0.071956

# %%
df.groupby(['state', 'monitoring_class']).agg({'period':'count'})
# Out:
#                         period
# state monitoring_class
# AP    SOYBEAN               30
# BA    CORN                 229
#       COTTON                36
#       SOYBEAN              457
# DF    CORN                  87
#       SOYBEAN               90
# GO    CORN                1183
#       COTTON                25
#       RICE                  72
#       SOYBEAN             2537
# MA    CORN                 380
#       SOYBEAN             1278
# MG    CORN                2596
#       COTTON                73
#       SOYBEAN             2908
# MS    CORN                 443
#       COTTON                25
#       RICE                  42
#       SOYBEAN             2138
# MT    CORN                1284
#       COTTON               180
#       SOYBEAN             4370
# PA    CORN                 369
#       SOYBEAN              769
# PI    CORN                 223
#       COTTON                 5
#       SOYBEAN              758
# PR    CORN                2999
#       RICE                  45
#       SOYBEAN             3295
# RO    CORN                 313
#       SOYBEAN              995
# RR    SOYBEAN              238
# RS    CORN                1261
#       RICE                 181
#       SOYBEAN             1851
# SC    CORN                 634
#       RICE                  58
#       SOYBEAN              296
# SP    CORN                1518
#       COTTON                14
#       SOYBEAN             3679
# TO    CORN                 419
#       COTTON                23
#       RICE                  44
#       SOYBEAN             1242

# %% [markdown]
# ### 5.4 Analysis field_id (existem IDs duplicados para os talhões)

# %%
df['field_id'].nunique()
# Out:
# 28489

# %%
df[df.duplicated(['field_id','period'])]
# Out:
#       monitoring_class     period                                  fonte  \
# 6                 CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 29                CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 34                CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 39                CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# 55                CORN  2020/2021  Agrosatélite - Grãos Brasil 2020/2021
# ...                ...        ...                                    ...
# 46980             RICE  2021/2022       Conab - Arroz Irrigado 2021/2022
# 46999             RICE  2017/2018       Conab - Arroz Irrigado 2017/2018
# 47020             RICE  2019/2020       Conab - Arroz Irrigado 2019/2020
# 47038             RICE  2021/2022       Conab - Arroz Irrigado 2021/2022
# 47039             RICE  2021/2022       Conab - Arroz Irrigado 2021/2022
#
#       state        area   meso  \
# 6        BA    953564.0  220.0
# 29       BA  12082522.0  222.0
# 34       BA  14934182.0   63.0
# 39       BA   4422121.0  222.0
# 55       BA   1096067.0  220.0
# ...     ...         ...    ...
# 46980    GO    408391.0  551.0
# 46999    TO    971807.0   59.0
# 47020    RS    384161.0  493.0
# 47038    GO    125860.0  551.0
# 47039    GO    190511.0  551.0
#
#                                          eopath_location start_season  \
# 6      start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 29     start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 34     start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 39     start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# 55     start_2020-10-01_end_2021-07-01_monitoring_cla...   2020-10-01
# ...                                                  ...          ...
# 46980  start_2021-10-01_end_2022-06-01_monitoring_cla...   2021-10-01
# 46999  start_2017-10-01_end_2018-06-01_monitoring_cla...   2017-10-01
# 47020  start_2019-09-01_end_2020-06-01_monitoring_cla...   2019-09-01
# 47038  start_2021-10-01_end_2022-06-01_monitoring_cla...   2021-10-01
# 47039  start_2021-10-01_end_2022-06-01_monitoring_cla...   2021-10-01
#
#       end_season peak_start  ...  \
# 6     2021-07-01 2021-01-01  ...
# 29    2021-07-01 2021-01-01  ...
# 34    2021-07-01 2021-01-01  ...
# 39    2021-07-01 2021-01-01  ...
# 55    2021-07-01 2021-01-01  ...
# ...          ...        ...  ...
# 46980 2022-06-01 2021-12-01  ...
# 46999 2018-06-01 2017-12-01  ...
# 47020 2020-06-01 2019-11-01  ...
# 47038 2022-06-01 2021-12-01  ...
# 47039 2022-06-01 2021-12-01  ...
#
#                                             key_bucket  \
# 6      datasets/culture/culture_v02/corn_train_v2.gpkg
# 29     datasets/culture/culture_v02/corn_train_v2.gpkg
# 34                                                None
# 39     datasets/culture/culture_v02/corn_train_v2.gpkg
# 55                                                None
# ...                                                ...
# 46980    datasets/culture/culture_v02/rice_val_v2.gpkg
# 46999   datasets/culture/culture_v02/rice_test_v2.gpkg
# 47020   datasets/culture/culture_v02/rice_test_v2.gpkg
# 47038   datasets/culture/culture_v02/rice_test_v2.gpkg
# 47039   datasets/culture/culture_v02/rice_test_v2.gpkg
#
#                                       local_eopatch_path  \
# 6      /agrilearn_app/datasets/eopatchs/processed/SOY...
# 29     /agrilearn_app/datasets/eopatchs/processed/SOY...
# 34                                                  None
# 39     /agrilearn_app/datasets/eopatchs/processed/SOY...
# 55                                                  None
# ...                                                  ...
# 46980  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 46999  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47020  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47038  /agrilearn_app/datasets/eopatchs/processed/SOY...
# 47039  /agrilearn_app/datasets/eopatchs/processed/SOY...
#
#       total_imagens_do_intervalo total_de_imagem status_missing_images  \
# 6                             55              24                    OK
# 29                            55              28                    OK
# 34                          None            None                  None
# 39                            55              33                    OK
# 55                          None            None                  None
# ...                          ...             ...                   ...
# 46980                         55              20                    OK
# 46999                         55              29                    OK
# 47020                         55              28                    OK
# 47038                         68              28                    OK
# 47039                         68              30                    OK
#
#       days_gap  dates_diff mean_dates_diff  status_series_missing  \
# 6         None        None            5.00                     OK
# 29        None        None            5.00                     OK
# 34        None        None             NaN                   None
# 39        None        None            5.00                     OK
# 55        None        None             NaN                   None
# ...        ...         ...             ...                    ...
# 46980     None        None            5.00                     OK
# 46999     None        None            5.18                     OK
# 47020     None        None            5.19                     OK
# 47038     None        None            5.00                     OK
# 47039     None        None            5.34                     OK
#
#                                                 geometry
# 6      POLYGON ((-46.23854 -11.65442, -46.23862 -11.6...
# 29     POLYGON ((-46.15444 -13.83715, -46.15445 -13.8...
# 34     MULTIPOLYGON (((-46.57307 -11.36588, -46.57307...
# 39     POLYGON ((-45.7407 -14.02816, -45.72816 -14.01...
# 55     MULTIPOLYGON (((-45.92617 -11.53204, -45.92617...
# ...                                                  ...
# 46980  POLYGON ((-47.09137 -14.46074, -47.09155 -14.4...
# 46999  POLYGON ((-49.68549 -10.5037, -49.6819 -10.503...
# 47020  POLYGON ((-51.41222 -29.70816, -51.41241 -29.7...
# 47038  POLYGON ((-47.03756 -14.50845, -47.03755 -14.5...
# 47039  POLYGON ((-47.03426 -14.51282, -47.03426 -14.5...
#
# [12830 rows x 54 columns]

# %%
df[df.duplicated(['field_id','period'])]['field_id'].unique()
# Out:
# array(['2143_1', '2229_2', '538_16', '2259_0', '2164_3', '2145_2',
#        '2209_5', '2136_0', '537_14', None, '11506_5', '11502_20',
#        '1279_3', '11203_0', '11219_3', '11013_4', '11353_0', '10760_2',
#        '11399_2', '11205_0', '1276_2', '11327_9', '11463_1', '11313_9',
#        '10783_1', '11480_0', '557_2', '1887_3', '1800_0', '1584_3',
#        '1765_5', '593_3', '1667_1', '563_4', '1733_1', '2779_1', '2549_3',
#        '3622_2', '2312_17', '2644_2', '3938_2', '4038_5', '2809_5',
#        '2449_3', '4166_1', '3617_2', '3285_1', '3835_4', '2544_10',
#        '2344_4', '3043_4', '3982_1', '2355_3', '3602_0', '674_5',
#        '2471_2', '3038_0', '2448_8', '3937_2', '10311_4', '10217_2',
#        '10384_5', '10533_7', '10527_3', '10463_5', '1180_9', '10533_11',
#        '10534_1', '10544_1', '10503_0', '10657_1', '1226_2', '10441_5',
#        '10414_15', '10394_3', '10437_4', '10437_10', '10606_10', '511_3',
#        '511_1', '1430_6', '2083_7', '1990_12', '1992_10', '6343_9',
#        '6435_1', '905_2', '6054_2', '5682_1', '6634_1', '6514_1',
#        '6889_0', '5750_2', '6094_5', '5618_5', '7074_3', '6152_1',
#        '6332_1', '5754_4', '885_2', '6533_1', '6452_1', '6352_14',
#        '6118_3', '5617_4', '5882_2', '6334_2', '1132_4', '8517_2',
#        '9550_2', '9071_18', '9284_5', '1172_1', '8584_4', '9003_5',
#        '9671_5', '9006_2', '9101_0', '1139_0', '1174_5', '8446_3',
#        '7726_3', '7711_3', '7723_3', '7661_45', '8075_8', '4412_5',
#        '5045_0', '4548_5', '5309_4', '4304_0', '4789_2', '4738_2',
#        '772_1', '5109_1', '4751_1', '5256_4', '5247_3', '794_1', '5416_3',
#        '4437_1', '4427_6', '4343_5', '4287_2', '731_1', '1524_11',
#        '524_2', '1578_1', '1528_5', '1816_2', '827_1', '2361_4', '9182_8',
#        '1173_1', '1337_0', '1337_2', '2563_2', '2960_1', '8903_2',
#        '5945_2', '641_4', '2500_3', '6237_6', '2252_3', '1588_1',
#        '1534_8', '598_3', '616_5', '2553_2', '5119_5', '1464_2', '6296_1',
#        '4480_4', '5523_3', '4487_3', '1645_3', '1309_2', '5916_1',
#        '5942_1', '6931_3', '3189_1', '6196_1', '7093_0', '3321_3',
#        '5851_2', '1553_1', '9665_1', '844_2', '2910_1', '10134_3',
#        '2893_1', '11013_3', '7912_1', '9134_3', '7203_1', '3183_1',
#        '4370_1', '4356_3', '6198_2', '6956_2', '5767_1', '2367_1',
#        '3353_2', '7399_3', '6306_1', '3373_2', '11232_2', '6212_1',
#        '573_0', '5747_1', '5265_0', '2626_2', '2573_13', '2511_3',
#        '2572_3', '6611_1', '9_2', '14_3', '23_1', '35_1', '40_8', '40_10',
#        '41_5', '41_6', '83_1', '126_1', '134_2', '140_2', '142_0',
#        '146_0', '157_1', '161_5', '180_1', '187_1', '201_3', '202_1',
#        '210_1', '214_0', '216_3', '229_6', '237_1', '266_1', '275_2',
#        '280_2', '281_2', '282_1', '309_2', '315_4', '315_6', '356_1',
#        '363_0', '371_3', '372_4', '373_4', '397_0', '416_1', '445_10',
#        '460_1', '460_3', '470_1', '476_1', '561_1', '639_2', '776_0',
#        '785_2', '801_3', '801_6', '803_11', '803_12', '827_0', '847_3',
#        '849_4', '850_3', '850_4', '850_5', '854_4', '854_5', '859_4',
#        '859_10', '859_16', '882_2', '940_1', '944_1', '43_1', '140_1',
#        '1_0', '1_2', '6_2', '8_3', '21_0', '48_4', '61_3', '61_7',
#        '62_18', '78_0', '78_3', '89_2', '89_4', '92_4', '113_2', '132_3',
#        '147_9', '147_12', '148_3', '148_4', '148_9', '154_2', '170_3',
#        '172_2', '185_1', '209_3', '219_2', '231_3', '231_4', '235_4',
#        '271_0', '307_1', '314_2', '319_1', '324_2', '346_0', '354_4',
#        '356_3', '357_0', '377_0', '378_3', '388_2', '390_0', '418_1',
#        '422_0', '426_1', '465_3', '472_3', '495_1', '504_0', '513_0',
#        '527_1', '575_6', '593_4', '599_2', '718_7', '739_3', '790_2',
#        '802_3', '803_4', '803_9', '815_2', '818_3', '818_10', '818_15',
#        '828_5', '831_4', '838_4', '841_2', '847_13', '859_6', '859_13',
#        '863_2', '865_2', '869_3', '870_7', '873_1', '877_8', '878_7',
#        '888_4', '891_1', '891_2', '891_6', '911_1', '913_2', '915_4',
#        '917_3', '917_8', '925_5', '929_3', '932_2', '932_11', '932_15',
#        '936_1', '955_4', '956_5', '958_4', '964_1', '976_6', '991_2',
#        '92_5', '389_0', '0_2', '0_4', '0_7', '65_0', '73_2', '91_6',
#        '177_2', '181_8', '183_1', '198_2', '242_4', '249_1', '249_9',
#        '309_3', '309_8', '316_3', '316_5', '321_2', '325_3', '325_5',
#        '347_0', '348_1', '362_2', '380_3', '380_9', '392_5', '452_4',
#        '453_4', '483_5', '273_1', '17_1', '26_3', '27_2', '32_2', '66_4',
#        '14_0', '14_1', '25_4', '53_2', '66_0', '84_10', '97_0', '0_1',
#        '50_2', '98_0', '100_0'], dtype=object)

# %%
#df[df['field_id'].isin(['0_6'])].to_csv('/agrilearn_app/datasets/cana-v1/csvs/duplicated_lines_CANA-sample-02.csv')

# %%
df[['cultura_2', 'monitoring_class']]
# Out:
#       cultura_2 monitoring_class
# 0          None             CORN
# 1          None             CORN
# 4          None             CORN
# 5          None             CORN
# 6          None             CORN
# ...         ...              ...
# 47037      None             RICE
# 47038      None             RICE
# 47039      None             RICE
# 47047      None             RICE
# 47060      None             RICE
#
# [41692 rows x 2 columns]

# %% [markdown]
# ### 5.5 Analysis of length_of_season (LOS)

# %%
df.groupby('LOS').agg(omission_count=('geometry','count')).sort_values('omission_count', ascending=False)
# Out:
#        omission_count
# LOS
# 130.0            3124
# 125.0            2906
# 135.0            2896
# 140.0            2787
# 120.0            2654
# ...               ...
# 172.0               1
# 178.0               1
# 182.0               1
# 188.0               1
# 218.0               1
#
# [66 rows x 1 columns]

# %% [markdown]
# ### 5.6 Tamanho do Talhão

# %%
df.columns
# Out:
# Index(['monitoring_class', 'period', 'fonte', 'state', 'area', 'meso',
#        'eopath_location', 'start_season', 'end_season', 'peak_start',
#        'peak_end', 'field_id', 'planting_start', 'planting_end', 'cycle_start',
#        'cycle_end', 'LOS', 'is_valid', 'is_valid_cvt', 'start_of_season',
#        'end_of_season', 'peaks', 'length_of_season', 'set_type',
#        'sampled_date', 'micro', 'peak_of_season', 'is_valid_metrics',
#        'sos_valid', 'pos_valid', 'eos_valid', 'los_valid', 'start_of_cycle',
#        'end_of_cycle', 'length_of_cycle', 'is_valid_POS', 'is_valid_LOS',
#        'dataset_part', 'cultura_2', 'obs_extra', 'sentinel_eopatch_current',
#        'contour_score', 'contour_selected_timestamp', 'compac_index',
#        'key_bucket', 'local_eopatch_path', 'total_imagens_do_intervalo',
#        'total_de_imagem', 'status_missing_images', 'days_gap', 'dates_diff',
#        'mean_dates_diff', 'status_series_missing', 'geometry'],
#       dtype='object')

# %%
# # discretização ()
# df['area_ha_cat'] = pd.cut(df['area_ha'], bins=[0, 10, 100, np.inf], labels=['pequena', "média", "grande"])

# %%
# df.groupby('area_ha_cat').agg(total=('geometry','count'))

# %%
# gdf.to_file(f"/agrilearn_app/datasets/base/geopackage/processed/{filename}", driver='GPKG', engine='fiona')

# %% [markdown]
# ## 7. Generating Html Report

# %%
# from ydata_profiling import ProfileReport
# from ydata_profiling.config import Settings
# %matplotlib inline

# %%
# df_copy = gdf.drop(columns=['cultura_2', 'geometry'])  # Supondo que 'cultura_2' seja a coluna problemática

# %%
# df_e_object = df_copy.select_dtypes(exclude=['object'])
# df_e_object

# %%
# df_i_object = df_copy.select_dtypes(include=['object'])
# df_i_object

# %%
# df_e_object_colums = df_copy.select_dtypes(exclude=['object']).columns

# %%
# title = "data_report_06_12_2024_cana_data"
# config = Settings()
# config.vars.cat.words = False  # Desativa a nuvem de palavras
# report  = ProfileReport(df=df_copy[list(df_e_object_colums) + ['monitoring_class', 'state', 'period', 'fonte']], 
#                         title=title,
#                         minimal=False,
#                         config=config)

# report.to_file(f'{title}.html')

# %%
# df_number = gdf.select_dtypes(exclude=['float','int', 'datetime'])
# df_number
